# %%
#Debugging 23-09-2023
#UI == pygame
#Implementado gráfico Max-Boltz
#Testar colisão por grid - logic
#Colisões e previsão funcionam + grid (inherited 6.10)
#Colisão inelástica e elástica implementada
#Colisão 'no future' mantida por causa de stuttering no pygame
#Colisão futura implementada em classe Particula
#Fazer: reação química


import math
import random
import warnings
import pygame
from pygame.locals import *
from sys import exit
import numpy as np
import matplotlib.pyplot as plt

# Constants
FPS = 60
DT = 1/FPS
ALTURA_CAIXA = 500
LARGURA_CAIXA = 500
NUM_PARTICULAS = 25
GRID_SIZE = 10
FUTURE_FACTOR = 2
TIPO_COLISAO = 'elastic'
COEFICIENTE_RESTITUICAO = 0.1 #coeficiente de restituição

# Colors
WHITE = (255, 255, 255)

class Particula:
    def __init__(self, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor):
        #self.p_type = str(p_type)
        self.massa = float(massa)
        self.raio = float(raio)
        self.vel_x = float(vel_x)
        self.vel_y = float(vel_y)
        self.x = float(x)
        self.y = float(y)
        self.x_future = float(x_future)
        self.y_future = float(y_future)
        self.cor = cor

    def deslocar(self):

        self.x += self.vel_x * DT
        self.y += self.vel_y * DT

        # Colisao parede
        if self.x < self.raio or self.x > LARGURA_CAIXA - self.raio:
            self.vel_x *= -1
        if self.y < self.raio or self.y > ALTURA_CAIXA - self.raio:
            self.vel_y *= -1

    def next_position(self):
        self.x_future = self.x + self.vel_x * DT * FUTURE_FACTOR
        self.y_future = self.y + self.vel_y * DT * FUTURE_FACTOR

class Grid:
    def __init__(self, width, height, cell_size):
        self.width = width
        self.height = height
        self.cell_size = cell_size
        self.num_cols = int(width / cell_size)
        self.num_rows = int(height / cell_size)
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #cria uma grid nova

    def clear(self):
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #'limpa' a grid

    def index(self, x, y):
        col = int(x / self.cell_size)
        row = int(y / self.cell_size)
        
        # Ensure col and row are within bounds
        col = max(0, min(col, self.num_cols - 1))
        row = max(0, min(row, self.num_rows - 1))
        
        return col + row * self.num_cols

    def insert(self, particle):
        index = self.index(particle.x, particle.y)
        self.grid[index].append(particle)

    def get_particles_in_cell(self, x, y):
        index = self.index(x, y)
        return self.grid[index]

    def update_grid(self, particles):
        self.clear()
        for particle in particles.values():
            self.insert(particle)

    def check_grid_collision(self, particles, grid):
        for particle in particles.values():
            cell_x = int(particle.x / grid.cell_size)
            cell_y = int(particle.y / grid.cell_size)

            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    neighbor_x = cell_x + dx
                    neighbor_y = cell_y + dy
                    if 0 <= neighbor_x < grid.num_cols and 0 <= neighbor_y < grid.num_rows:
                        for neighbor in grid.get_particles_in_cell(neighbor_x * grid.cell_size, neighbor_y * grid.cell_size):
                            if particle != neighbor and check_collision(particle, neighbor):
                                #print(f"Collision detected between {particle} and {neighbor}")
                                resolve_collision(particle, neighbor, collision_type=TIPO_COLISAO)

def check_collision(p1, p2):

    p1.next_position() #proxima_posicao

    p2.next_position() #proxima_posicao

    distance_future = math.sqrt((p2.x_future - p1.x_future)**2 + (p2.y_future - p1.y_future)**2)
    distance = math.sqrt((p2.x - p1.x)**2 + (p2.y - p1.y)**2)
    if ((distance <= p1.raio + p2.raio) or (distance_future <= p1.raio + p2.raio)) == True:
        return True
    else:
        return False


def resolve_collision(p1, p2, collision_type='elastic'):
    x1 = np.array([p1.x, p1.y])
    x2 = np.array([p2.x, p2.y])

    #print('arrays_x:', x1, x2)

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    #print('arrays_v:', v1, v2)

    if collision_type == 'elastic' or collision_type == 'elastica':
        #print('elastica')

        C = 1

    if collision_type == 'inelastic' or collision_type == 'inelastica':
        #print('inelastica')

        C = COEFICIENTE_RESTITUICAO

    new_v1 = v1 - ((((C * p2.massa) + p2.massa) / (p1.massa + p2.massa)) * ((np.dot((v1 - v2),(x1 - x2))) / ((np.linalg.norm(x1 - x2))**2)) * (x1 - x2))
    new_v2 = v2 - ((((C * p1.massa) + p1.massa) / (p1.massa + p2.massa)) * ((np.dot((v2 - v1),(x2 - x1))) / ((np.linalg.norm(x2 - x1))**2)) * (x2 - x1))

    p1.vel_x = new_v1[0]
    p1.vel_y = new_v1[1]
    p2.vel_x = new_v2[0]
    p2.vel_y = new_v2[1]

    #print(p1.vel_x, p1.vel_y, p2.vel_x, p2.vel_y)

#src_elastica = https://en.wikipedia.org/wiki/Elastic_collision#Two-dimensional_collision_with_two_moving_objects
#src_inelastica = https://physics.stackexchange.com/questions/708495/angle-free-two-dimensional-inelastic-collision-formula


def gerar_particula(n_particulas):
    particulas = {}

    #atomos
    atomos = {
        "Na": {"massa": 22, "raio": 22, "color": (255, 0, 0)},
        "Cl": {"massa": 35, "raio": 35, "color": (0, 255, 0)},

    }

    for particle_index in range(1, n_particulas + 1):
        #escolha de distribuição aleatória
        atomos_selecionar = random.choice(list(atomos.keys()))

        attributes = atomos[atomos_selecionar]
        
        massa = attributes["massa"]
        raio = attributes["raio"]
        vel_x = random.uniform(-100, 100) #velocidade inicial não especificada
        vel_y = random.uniform(-100, 100)
        x = random.uniform(raio, LARGURA_CAIXA - raio)
        y = random.uniform(raio, ALTURA_CAIXA - raio)
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = attributes["color"]
        nome_particula = f"{atomos_selecionar}_{particle_index}" 
        particle_instance = Particula(massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        particulas[nome_particula] = particle_instance

    return particulas


def intersection_pos_checker(particles,iteration_max = 100):
    iteration_count = 0
    intersection = False
    for particle_name, particle_instance in particles.items():
        for other_particle_name, other_particle_instance in particles.items():
            if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                particle_move = random.choice([[particle_name,particle_instance], [other_particle_name,other_particle_instance]])
                new_x = random.uniform(particle_move[1].raio, LARGURA_CAIXA - (particle_move[1].raio))
                new_y = random.uniform(particle_move[1].raio, ALTURA_CAIXA - (particle_move[1].raio))
                particles[particle_move[0]].x = new_x
                particles[particle_move[0]].y = new_y
                iteration_count +=1
                #print(particles[particle_move[0]].y) #verificar coordenadas alteradas

                intersection = True
                if iteration_max == iteration_count:
                    warnings.warn(f'{iteration_max} iterações atingidas. Deve haver partículas sobrepostas. Altere o tamanho da caixa.')
                    return particles
    
    if intersection == True:
        #print('True')
        return intersection_pos_checker(particles)

    if intersection == False:
        #print('False')
        return particles

def create_particle_sprites(particles):
    sprites = pygame.sprite.Group()
    for particle_instance in particles.values():
        circle = pygame.Surface((particle_instance.raio * 2, particle_instance.raio * 2), pygame.SRCALPHA)
        pygame.draw.circle(circle, particle_instance.cor, (particle_instance.raio, particle_instance.raio), particle_instance.raio)
        sprite = pygame.sprite.Sprite()
        sprite.image = circle
        sprite.rect = sprite.image.get_rect(center=(particle_instance.x, particle_instance.y))
        sprites.add(sprite)
    return sprites


def main():
    final_speeds = []
    pygame.init()
    screen = pygame.display.set_mode((LARGURA_CAIXA, ALTURA_CAIXA))
    pygame.display.set_caption("Collision Simulation")

    particles = gerar_particula(NUM_PARTICULAS)
    particles = intersection_pos_checker(particles)
    sprites = create_particle_sprites(particles)

    grid = Grid(LARGURA_CAIXA, ALTURA_CAIXA, GRID_SIZE)

    clock = pygame.time.Clock()


    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                # Pegar velocidades finais de todas as particulas
                for particle_instance in particles.values():
                    final_speed = math.sqrt(particle_instance.vel_x**2 + particle_instance.vel_y**2)
                    final_speeds.append(final_speed)

                # Barplot/histograma das velocidades Max-Boltz.
                fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
                plt.hist(final_speeds, bins=25, color='blue', edgecolor='black', alpha=0.7)
                plt.xlabel('Velocidade')
                plt.ylabel('Frequência')
                plt.title('Histograma das velocidades finais')
                plt.grid(True)
                fig.tight_layout()
                fig.savefig("max-boltz_6_11.png")  # Salva a figura

                plt.show()
                exit()

        # Update the grid with the new particle positions
        grid.update_grid(particles)

        # Check for collisions based on the updated grid
        grid.check_grid_collision(particles, grid)

        # Resolve collisions after updating positions
        for particle_name, particle_instance in particles.items():
            for other_particle_name, other_particle_instance in particles.items():
                if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                    #print(f"Collision detected between {particle_name} and {other_particle_name}")
                    resolve_collision(particle_instance, other_particle_instance, collision_type=TIPO_COLISAO)

        # Update particle positions after collision detection
        for particle_name, particle_instance in particles.items():
            particle_instance.deslocar()

        # Update sprite positions
        for sprite, particle_instance in zip(sprites, particles.values()):
            sprite.rect.center = (particle_instance.x, particle_instance.y)

        screen.fill(WHITE)
        sprites.draw(screen)

        pygame.display.flip()
        clock.tick(FPS)

if __name__ == "__main__":
    main()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\venv\ilumpy-VS\lib\site-packages\IPython\core\interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#Debugging 23-09-2023
#UI == pygame
#Implementado gráfico Max-Boltz
#Testar colisão por grid - logic
#Colisões e previsão funcionam + grid (inherited 6.10)
#Colisão inelástica e elástica implementada
#Colisão 'no future' mantida por causa de stuttering no pygame
#Colisão futura implementada em classe Particula
#Fazer: reação química


import math
import random
import warnings
import pygame
from pygame.locals import *
from sys import exit
import numpy as np
import matplotlib.pyplot as plt

# Constants
FPS = 60
DT = 1/FPS
ALTURA_CAIXA = 500
LARGURA_CAIXA = 500
NUM_PARTICULAS = 2
GRID_SIZE = 10
FUTURE_FACTOR = 2
TIPO_COLISAO = 'partial_inelastic'
COEFICIENTE_RESTITUICAO = 0.0 #coeficiente de restituição

# Indexes de moléculas das reações
NA_CL_INDEX = 0

# Colors
WHITE = (255, 255, 255)

class Particula:
    def __init__(self, p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor):
        self.p_type = p_type
        self.massa = float(massa)
        self.raio = float(raio)
        self.vel_x = float(vel_x)
        self.vel_y = float(vel_y)
        self.x = float(x)
        self.y = float(y)
        self.x_future = float(x_future)
        self.y_future = float(y_future)
        self.cor = cor

    def deslocar(self):

        self.x += self.vel_x * DT
        self.y += self.vel_y * DT

        # Colisao parede
        if self.x < self.raio or self.x > LARGURA_CAIXA - self.raio:
            self.vel_x *= -1
        if self.y < self.raio or self.y > ALTURA_CAIXA - self.raio:
            self.vel_y *= -1

    def next_position(self):
        self.x_future = self.x + self.vel_x * DT * FUTURE_FACTOR
        self.y_future = self.y + self.vel_y * DT * FUTURE_FACTOR

class Grid:
    def __init__(self, width, height, cell_size):
        self.width = width
        self.height = height
        self.cell_size = cell_size
        self.num_cols = int(width / cell_size)
        self.num_rows = int(height / cell_size)
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #cria uma grid nova

    def clear(self):
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #'limpa' a grid

    def index(self, x, y):
        col = int(x / self.cell_size)
        row = int(y / self.cell_size)
        
        # Ensure col and row are within bounds
        col = max(0, min(col, self.num_cols - 1))
        row = max(0, min(row, self.num_rows - 1))
        
        return col + row * self.num_cols

    def insert(self, particle):
        index = self.index(particle.x, particle.y)
        self.grid[index].append(particle)

    def get_particles_in_cell(self, x, y):
        index = self.index(x, y)
        return self.grid[index]

    def update_grid(self, particles):
        self.clear()
        for particle in particles.values():
            self.insert(particle)

    def check_grid_collision(self, particles, grid):
        for particle in particles.values():
            cell_x = int(particle.x / grid.cell_size)
            cell_y = int(particle.y / grid.cell_size)

            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    neighbor_x = cell_x + dx
                    neighbor_y = cell_y + dy
                    if 0 <= neighbor_x < grid.num_cols and 0 <= neighbor_y < grid.num_rows:
                        for neighbor in grid.get_particles_in_cell(neighbor_x * grid.cell_size, neighbor_y * grid.cell_size):
                            if particle != neighbor and check_collision(particle, neighbor):
                                #print(f"Collision detected between {particle} and {neighbor}")
                                resolve_collision(particle, neighbor, collision_type=TIPO_COLISAO)

def check_collision(p1, p2):

    p1.next_position() #proxima_posicao

    p2.next_position() #proxima_posicao

    distance_future = math.sqrt((p2.x_future - p1.x_future)**2 + (p2.y_future - p1.y_future)**2)
    distance = math.sqrt((p2.x - p1.x)**2 + (p2.y - p1.y)**2)
    if ((distance <= p1.raio + p2.raio) or (distance_future <= p1.raio + p2.raio)) == True:
        return True
    else:
        return False


def reaction_collision(particles, p1, p1_index, p2, p2_index):

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    vel_new_particle = ((p1.massa * v1) + (p2.massa * v2)) / (p1.massa + p2.massa) #apenas momento conservado

    #print('arrays_reaction_v:', v1, v2)

    CM_x = (p1.massa * p1.x + p2.massa * p2.x) / (p1.massa + p2.massa)
    CM_y = (p1.massa * p1.y + p2.massa * p2.y) / (p1.massa + p2.massa)

    #print('arrays_reaction_CM:', CM_x, CM_y )


    if p1.p_type == 'Na' and p2.p_type == 'Cl':

        global NA_CL_INDEX

        p_type = 'NaCl'
        massa = (p1.massa + p2.massa)
        raio = massa
        vel_x = vel_new_particle[0]
        vel_y = vel_new_particle[1]
        x = CM_x
        y = CM_y
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = (125, 125, 125)
        nome_particula = f"{p_type}_{NA_CL_INDEX}" 
        particle_instance = Particula(p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        NA_CL_INDEX += 1

        particles.update({nome_particula : particle_instance})
        del particles[p1_index]
        del particles[p2_index]

    else:
        resolve_collision(p1,p2,collision_type=TIPO_COLISAO)




def resolve_collision(p1, p2, collision_type='elastic'):
    x1 = np.array([p1.x, p1.y])
    x2 = np.array([p2.x, p2.y])

    #print('arrays_x:', x1, x2)

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    #print('arrays_v:', v1, v2)

    if collision_type == 'elastic' or collision_type == 'elastica':
        #print('elastica')

        C = 1

    if collision_type == 'partial_inelastic' or collision_type == 'parcial_inelastica':
        #print('inelastica')

        C = COEFICIENTE_RESTITUICAO

    new_v1 = v1 - ((((C * p2.massa) + p2.massa) / (p1.massa + p2.massa)) * ((np.dot((v1 - v2),(x1 - x2))) / ((np.linalg.norm(x1 - x2))**2)) * (x1 - x2))
    new_v2 = v2 - ((((C * p1.massa) + p1.massa) / (p1.massa + p2.massa)) * ((np.dot((v2 - v1),(x2 - x1))) / ((np.linalg.norm(x2 - x1))**2)) * (x2 - x1))

    p1.vel_x = new_v1[0]
    p1.vel_y = new_v1[1]
    p2.vel_x = new_v2[0]
    p2.vel_y = new_v2[1]

    print(p1.vel_x, p1.vel_y, p2.vel_x, p2.vel_y)

#src_elastica = https://en.wikipedia.org/wiki/Elastic_collision#Two-dimensional_collision_with_two_moving_objects
#src_inelastica = https://physics.stackexchange.com/questions/708495/angle-free-two-dimensional-inelastic-collision-formula


def gerar_particula(n_particulas):
    particulas = {}

    #atomos
    atomos = {
        "Na": {"massa": 22, "raio": 22, "color": (255, 0, 0)},
        "Cl": {"massa": 35, "raio": 35, "color": (0, 255, 0)},

    }

    for particle_index in range(1, n_particulas + 1):
        #escolha de distribuição aleatória
        atomos_selecionar = random.choice(list(atomos.keys()))

        attributes = atomos[atomos_selecionar]

        p_type = atomos_selecionar
        massa = attributes["massa"]
        raio = attributes["raio"]
        vel_x = random.uniform(-100, 100) #velocidade inicial não especificada
        vel_y = random.uniform(-100, 100)
        x = random.uniform(raio, LARGURA_CAIXA - raio)
        y = random.uniform(raio, ALTURA_CAIXA - raio)
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = attributes["color"]
        nome_particula = f"{atomos_selecionar}_{particle_index}" 
        particle_instance = Particula(p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        particulas[nome_particula] = particle_instance

    return particulas


def intersection_pos_checker(particles,iteration_max = 100):
    iteration_count = 0
    intersection = False
    for particle_name, particle_instance in particles.items():
        for other_particle_name, other_particle_instance in particles.items():
            if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                particle_move = random.choice([[particle_name,particle_instance], [other_particle_name,other_particle_instance]])
                new_x = random.uniform(particle_move[1].raio, LARGURA_CAIXA - (particle_move[1].raio))
                new_y = random.uniform(particle_move[1].raio, ALTURA_CAIXA - (particle_move[1].raio))
                particles[particle_move[0]].x = new_x
                particles[particle_move[0]].y = new_y
                iteration_count +=1
                #print(particles[particle_move[0]].y) #verificar coordenadas alteradas

                intersection = True
                if iteration_max == iteration_count:
                    warnings.warn(f'{iteration_max} iterações atingidas. Deve haver partículas sobrepostas. Altere o tamanho da caixa.')
                    return particles
    
    if intersection == True:
        #print('True')
        return intersection_pos_checker(particles)

    if intersection == False:
        #print('False')
        return particles

def create_particle_sprites(particles):
    sprites = pygame.sprite.Group()
    for particle_instance in particles.values():
        circle = pygame.Surface((particle_instance.raio * 2, particle_instance.raio * 2), pygame.SRCALPHA)
        pygame.draw.circle(circle, particle_instance.cor, (particle_instance.raio, particle_instance.raio), particle_instance.raio)
        sprite = pygame.sprite.Sprite()
        sprite.image = circle
        sprite.rect = sprite.image.get_rect(center=(particle_instance.x, particle_instance.y))
        sprites.add(sprite)
    return sprites


def main():
    final_speeds = []
    pygame.init()
    screen = pygame.display.set_mode((LARGURA_CAIXA, ALTURA_CAIXA))
    pygame.display.set_caption("Collision Simulation")

    particles = gerar_particula(NUM_PARTICULAS)
    particles = intersection_pos_checker(particles)
    sprites = create_particle_sprites(particles)

    grid = Grid(LARGURA_CAIXA, ALTURA_CAIXA, GRID_SIZE)

    clock = pygame.time.Clock()


    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                # Pegar velocidades finais de todas as particulas
                for particle_instance in particles.values():
                    final_speed = math.sqrt(particle_instance.vel_x**2 + particle_instance.vel_y**2)
                    final_speeds.append(final_speed)

                # Barplot/histograma das velocidades Max-Boltz.
                fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
                plt.hist(final_speeds, bins=25, color='blue', edgecolor='black', alpha=0.7)
                plt.xlabel('Velocidade')
                plt.ylabel('Frequência')
                plt.title('Histograma das velocidades finais')
                plt.grid(True)
                fig.tight_layout()
                fig.savefig("max-boltz_6_11.png")  # Salva a figura

                plt.show()
                exit()

        # Update the grid with the new particle positions
        grid.update_grid(particles)

        # Check for collisions based on the updated grid
        grid.check_grid_collision(particles, grid)

        # Resolve collisions after updating positions
        for particle_name, particle_instance in particles.items():
            for other_particle_name, other_particle_instance in particles.items():
                if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                    #print(f"Collision detected between {particle_name} and {other_particle_name}")
                    reaction_collision(particles,particle_instance,particle_name,other_particle_instance,other_particle_name)

        # Update particle positions after collision detection
        for particle_name, particle_instance in particles.items():
            particle_instance.deslocar()

        # Update sprite positions
        for sprite, particle_instance in zip(sprites, particles.values()):
            sprite.rect.center = (particle_instance.x, particle_instance.y)

        screen.fill(WHITE)
        sprites.draw(screen)

        pygame.display.flip()
        clock.tick(FPS)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 345
#     342         clock.tick(FPS)
#     344 if __name__ == "__main__":
# --> 345     main()
#
# Cell In[4], line 325, in main()
#     323 # Resolve collisions after updating positions
#     324 for particle_name, particle_instance in particles.items():
# --> 325     for other_particle_name, other_particle_instance in particles.items():
#     326         if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
#     327             #print(f"Collision detected between {particle_name} and {other_particle_name}")
#     328             reaction_collision(particles,particle_instance,particle_name,other_particle_instance,other_particle_name)
#
# RuntimeError: dictionary changed size during iteration

# %%
def iterar_reaction(particles):
    for particle_name, particle_instance in particles.items():
            for other_particle_name, other_particle_instance in particles.items():
                if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                    #print(f"Collision detected between {particle_name} and {other_particle_name}")
                    particles = reaction_collision(particles,particle_instance,particle_name,other_particle_instance,other_particle_name)
                    iterar_reaction(particles)

# %%
def reaction_collision(particles, p1, p1_index, p2, p2_index):

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    vel_new_particle = ((p1.massa * v1) + (p2.massa * v2)) / (p1.massa + p2.massa) #apenas momento conservado

    #print('arrays_reaction_v:', v1, v2)

    CM_x = (p1.massa * p1.x + p2.massa * p2.x) / (p1.massa + p2.massa)
    CM_y = (p1.massa * p1.y + p2.massa * p2.y) / (p1.massa + p2.massa)

    #print('arrays_reaction_CM:', CM_x, CM_y )


    if p1.p_type == 'Na' and p2.p_type == 'Cl':

        global NA_CL_INDEX

        p_type = 'NaCl'
        massa = (p1.massa + p2.massa)
        raio = massa
        vel_x = vel_new_particle[0]
        vel_y = vel_new_particle[1]
        x = CM_x
        y = CM_y
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = (125, 125, 125)
        nome_particula = f"{p_type}_{NA_CL_INDEX}" 
        particle_instance = Particula(p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        NA_CL_INDEX += 1

        particles.update({nome_particula : particle_instance})
        del particles[p1_index]
        del particles[p2_index]


    else:
        resolve_collision(p1,p2,collision_type=TIPO_COLISAO)

    return particles

# %%
#Debugging 23-09-2023
#UI == pygame
#Implementado gráfico Max-Boltz
#Testar colisão por grid - logic
#Colisões e previsão funcionam + grid (inherited 6.10)
#Colisão inelástica e elástica implementada
#Colisão 'no future' mantida por causa de stuttering no pygame
#Colisão futura implementada em classe Particula
#Fazer: reação química


import math
import random
import warnings
import pygame
from pygame.locals import *
from sys import exit
import numpy as np
import matplotlib.pyplot as plt

# Constants
FPS = 60
DT = 1/FPS
ALTURA_CAIXA = 500
LARGURA_CAIXA = 500
NUM_PARTICULAS = 2
GRID_SIZE = 10
FUTURE_FACTOR = 2
TIPO_COLISAO = 'elastic'
COEFICIENTE_RESTITUICAO = 0.0 #coeficiente de restituição

# Indexes de moléculas das reações
NA_CL_INDEX = 0

# Colors
WHITE = (255, 255, 255)

class Particula:
    def __init__(self, p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor):
        self.p_type = p_type
        self.massa = float(massa)
        self.raio = float(raio)
        self.vel_x = float(vel_x)
        self.vel_y = float(vel_y)
        self.x = float(x)
        self.y = float(y)
        self.x_future = float(x_future)
        self.y_future = float(y_future)
        self.cor = cor

    def deslocar(self):

        self.x += self.vel_x * DT
        self.y += self.vel_y * DT

        # Colisao parede
        if self.x < self.raio or self.x > LARGURA_CAIXA - self.raio:
            self.vel_x *= -1
        if self.y < self.raio or self.y > ALTURA_CAIXA - self.raio:
            self.vel_y *= -1

    def next_position(self):
        self.x_future = self.x + self.vel_x * DT * FUTURE_FACTOR
        self.y_future = self.y + self.vel_y * DT * FUTURE_FACTOR

class Grid:
    def __init__(self, width, height, cell_size):
        self.width = width
        self.height = height
        self.cell_size = cell_size
        self.num_cols = int(width / cell_size)
        self.num_rows = int(height / cell_size)
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #cria uma grid nova

    def clear(self):
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #'limpa' a grid

    def index(self, x, y):
        col = int(x / self.cell_size)
        row = int(y / self.cell_size)
        
        # Ensure col and row are within bounds
        col = max(0, min(col, self.num_cols - 1))
        row = max(0, min(row, self.num_rows - 1))
        
        return col + row * self.num_cols

    def insert(self, particle):
        index = self.index(particle.x, particle.y)
        self.grid[index].append(particle)

    def get_particles_in_cell(self, x, y):
        index = self.index(x, y)
        return self.grid[index]

    def update_grid(self, particles):
        self.clear()
        for particle in particles.values():
            self.insert(particle)

    def check_grid_collision(self, particles, grid):
        for particle in particles.values():
            cell_x = int(particle.x / grid.cell_size)
            cell_y = int(particle.y / grid.cell_size)

            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    neighbor_x = cell_x + dx
                    neighbor_y = cell_y + dy
                    if 0 <= neighbor_x < grid.num_cols and 0 <= neighbor_y < grid.num_rows:
                        for neighbor in grid.get_particles_in_cell(neighbor_x * grid.cell_size, neighbor_y * grid.cell_size):
                            if particle != neighbor and check_collision(particle, neighbor):
                                #print(f"Collision detected between {particle} and {neighbor}")
                                resolve_collision(particle, neighbor, collision_type=TIPO_COLISAO)

def check_collision(p1, p2):

    p1.next_position() #proxima_posicao

    p2.next_position() #proxima_posicao

    distance_future = math.sqrt((p2.x_future - p1.x_future)**2 + (p2.y_future - p1.y_future)**2)
    distance = math.sqrt((p2.x - p1.x)**2 + (p2.y - p1.y)**2)
    if ((distance <= p1.raio + p2.raio) or (distance_future <= p1.raio + p2.raio)) == True:
        return True
    else:
        return False


def reaction_collision(particles, p1, p1_index, p2, p2_index):

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    vel_new_particle = ((p1.massa * v1) + (p2.massa * v2)) / (p1.massa + p2.massa) #apenas momento conservado

    #print('arrays_reaction_v:', v1, v2)

    CM_x = (p1.massa * p1.x + p2.massa * p2.x) / (p1.massa + p2.massa)
    CM_y = (p1.massa * p1.y + p2.massa * p2.y) / (p1.massa + p2.massa)

    #print('arrays_reaction_CM:', CM_x, CM_y )

    new_particles = particles.copy()
    print('old_new_particles:', new_particles)
    #print(p1.p_type, p2.p_type)

    if (p1.p_type == 'Na' and p2.p_type == 'Cl') or (p1.p_type == 'Cl' and p2.p_type == 'Na'):
        #print(p1.p_type, p2.p_type, 'form NaCl')

        global NA_CL_INDEX

        p_type = 'NaCl'
        massa = (p1.massa + p2.massa)
        raio = massa
        vel_x = vel_new_particle[0]
        vel_y = vel_new_particle[1]
        x = CM_x
        y = CM_y
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = (125, 125, 125)
        nome_particula = f"{p_type}_{NA_CL_INDEX}" 
        particle_instance = Particula(p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        NA_CL_INDEX += 1

        new_particles.update({nome_particula : particle_instance})
        new_particles.pop(p1_index)
        new_particles.pop(p2_index)


    else:
        #print('does not react')
        resolve_collision(p1,p2,collision_type=TIPO_COLISAO)

    print('new_new_particles:',new_particles)
    return new_particles


def resolve_collision(p1, p2, collision_type='elastic'):
    x1 = np.array([p1.x, p1.y])
    x2 = np.array([p2.x, p2.y])

    #print('arrays_x:', x1, x2)

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    #print('arrays_v:', v1, v2)

    if collision_type == 'elastic' or collision_type == 'elastica':
        #print('elastica')

        C = 1

    if collision_type == 'partial_inelastic' or collision_type == 'parcial_inelastica':
        #print('inelastica')

        C = COEFICIENTE_RESTITUICAO

    new_v1 = v1 - ((((C * p2.massa) + p2.massa) / (p1.massa + p2.massa)) * ((np.dot((v1 - v2),(x1 - x2))) / ((np.linalg.norm(x1 - x2))**2)) * (x1 - x2))
    new_v2 = v2 - ((((C * p1.massa) + p1.massa) / (p1.massa + p2.massa)) * ((np.dot((v2 - v1),(x2 - x1))) / ((np.linalg.norm(x2 - x1))**2)) * (x2 - x1))

    p1.vel_x = new_v1[0]
    p1.vel_y = new_v1[1]
    p2.vel_x = new_v2[0]
    p2.vel_y = new_v2[1]

    print(p1.vel_x, p1.vel_y, p2.vel_x, p2.vel_y)

#src_elastica = https://en.wikipedia.org/wiki/Elastic_collision#Two-dimensional_collision_with_two_moving_objects
#src_inelastica = https://physics.stackexchange.com/questions/708495/angle-free-two-dimensional-inelastic-collision-formula

def iterar_reaction(particles):
    for particle_name, particle_instance in particles.items():
            for other_particle_name, other_particle_instance in particles.items():
                if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                    #print(f"Collision detected between {particle_name} and {other_particle_name}")
                    new_particles = reaction_collision(particles,particle_instance,particle_name,other_particle_instance,other_particle_name)
                    iterar_reaction(new_particles)


def gerar_particula(n_particulas):
    particulas = {}

    #atomos
    atomos = {
        "Na": {"massa": 22, "raio": 22, "color": (255, 0, 0)},
        "Cl": {"massa": 35, "raio": 35, "color": (0, 255, 0)},

    }

    for particle_index in range(1, n_particulas + 1):
        #escolha de distribuição aleatória
        atomos_selecionar = random.choice(list(atomos.keys()))

        attributes = atomos[atomos_selecionar]

        p_type = atomos_selecionar
        massa = attributes["massa"]
        raio = attributes["raio"]
        vel_x = random.uniform(-100, 100) #velocidade inicial não especificada
        vel_y = random.uniform(-100, 100)
        x = random.uniform(raio, LARGURA_CAIXA - raio)
        y = random.uniform(raio, ALTURA_CAIXA - raio)
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = attributes["color"]
        nome_particula = f"{atomos_selecionar}_{particle_index}" 
        particle_instance = Particula(p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        particulas[nome_particula] = particle_instance

    return particulas


def intersection_pos_checker(particles,iteration_max = 100):
    iteration_count = 0
    intersection = False
    for particle_name, particle_instance in particles.items():
        for other_particle_name, other_particle_instance in particles.items():
            if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                particle_move = random.choice([[particle_name,particle_instance], [other_particle_name,other_particle_instance]])
                new_x = random.uniform(particle_move[1].raio, LARGURA_CAIXA - (particle_move[1].raio))
                new_y = random.uniform(particle_move[1].raio, ALTURA_CAIXA - (particle_move[1].raio))
                particles[particle_move[0]].x = new_x
                particles[particle_move[0]].y = new_y
                iteration_count +=1
                #print(particles[particle_move[0]].y) #verificar coordenadas alteradas

                intersection = True
                if iteration_max == iteration_count:
                    warnings.warn(f'{iteration_max} iterações atingidas. Deve haver partículas sobrepostas. Altere o tamanho da caixa.')
                    return particles
    
    if intersection == True:
        #print('True')
        return intersection_pos_checker(particles)

    if intersection == False:
        #print('False')
        return particles

def create_particle_sprites(particles):
    sprites = pygame.sprite.Group()
    for particle_instance in particles.values():
        circle = pygame.Surface((particle_instance.raio * 2, particle_instance.raio * 2), pygame.SRCALPHA)
        pygame.draw.circle(circle, particle_instance.cor, (particle_instance.raio, particle_instance.raio), particle_instance.raio)
        sprite = pygame.sprite.Sprite()
        sprite.image = circle
        sprite.rect = sprite.image.get_rect(center=(particle_instance.x, particle_instance.y))
        sprites.add(sprite)
    print(sprites)
    return sprites


def main():
    final_speeds = []
    pygame.init()
    screen = pygame.display.set_mode((LARGURA_CAIXA, ALTURA_CAIXA))
    pygame.display.set_caption("Collision Simulation")

    particles = gerar_particula(NUM_PARTICULAS)
    particles = intersection_pos_checker(particles)
    sprites = create_particle_sprites(particles)

    grid = Grid(LARGURA_CAIXA, ALTURA_CAIXA, GRID_SIZE)

    clock = pygame.time.Clock()


    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                # Pegar velocidades finais de todas as particulas
                for particle_instance in particles.values():
                    final_speed = math.sqrt(particle_instance.vel_x**2 + particle_instance.vel_y**2)
                    final_speeds.append(final_speed)

                # Barplot/histograma das velocidades Max-Boltz.
                fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
                plt.hist(final_speeds, bins=25, color='blue', edgecolor='black', alpha=0.7)
                plt.xlabel('Velocidade')
                plt.ylabel('Frequência')
                plt.title('Histograma das velocidades finais')
                plt.grid(True)
                fig.tight_layout()
                fig.savefig("max-boltz_6_11.png")  # Salva a figura

                plt.show()
                exit()

        # Update the grid with the new particle positions
        grid.update_grid(particles)

        # Check for collisions based on the updated grid
        grid.check_grid_collision(particles, grid)

        # Reação
        iterar_reaction(particles)

        # Update particle positions after collision detection
        for particle_name, particle_instance in particles.items():
            particle_instance.deslocar()

        # Update sprite positions
        for sprite, particle_instance in zip(sprites, particles.values()):
            sprite.rect.center = (particle_instance.x, particle_instance.y)

        screen.fill(WHITE)
        sprites.draw(screen)

        pygame.display.flip()
        clock.tick(FPS)

if __name__ == "__main__":
    main()
# Out:
# <Group(2 sprites)>
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_0': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_1': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_2': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_3': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_4': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_5': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_6': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_7': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_8': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_9': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_10': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_11': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_12': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_13': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_14': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_15': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_16': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_17': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_18': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_19': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_20': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_21': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_22': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_23': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_24': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_25': <__main__.Particula object at 0x00000241EC5A58B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_26': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_27': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_28': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_29': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_30': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_31': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_32': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_33': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_34': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_35': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_36': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_37': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_38': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_39': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_40': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_41': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_42': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_43': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_44': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_45': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_46': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_47': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_48': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_49': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_50': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_51': <__main__.Particula object at 0x00000241EC5A55B0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_52': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_53': <__main__.Particula object at 0x00000241EC5A5CA0>}
# 0.40511931476402196 22.35934782273598 107.72913161918885 -15.818500762239879
# -19.50943205702164 -25.993275040543182 80.38364505409632 28.754920226240916
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_54': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_55': <__main__.Particula object at 0x00000241EC5A5CA0>}
# 3.7526147259779776 29.60703736646534 102.4035707377121 -27.34891594544568
# -19.509432057021698 -25.99327504054318 80.38364505409635 28.754920226240912
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_56': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_57': <__main__.Particula object at 0x00000241EC5A5CA0>}
# 10.937353132834772 38.90919784418741 90.97330509043992 -42.14780761454898
# -19.509432057021726 -25.99327504054318 80.38364505409636 28.75492022624091
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_58': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_59': <__main__.Particula object at 0x00000241EC5A5CA0>}
# 26.12347674861104 48.689523059871924 66.8135629744322 -57.70741591222888
# -19.509432057021726 -25.993275040543175 80.38364505409636 28.75492022624091
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_60': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_61': <__main__.Particula object at 0x00000241EC5A5CA0>}
# 53.74009973732953 49.945797400222375 22.878026401470954 -59.70603418096824
# -19.509432057021726 -25.993275040543175 80.38364505409636 28.75492022624091
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_62': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_63': <__main__.Particula object at 0x00000241EC5A5CA0>}
# 81.67834337875227 26.198299119192026 -21.56917939170158 -21.925923279329044
# -19.50943205702173 -25.993275040543168 80.38364505409636 28.754920226240905
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_64': <__main__.Particula object at 0x00000241EDBB5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_65': <__main__.Particula object at 0x00000241EC5A5760>}
# 82.29001238562353 -9.577099320697812 -22.542289175360395 34.98948332958661
# -19.509432057021726 -25.99327504054319 80.38364505409636 28.754920226240912
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_66': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_67': <__main__.Particula object at 0x00000241EC5A5760>}
# 65.395616664597 -29.492087243818595 4.335158562636352 66.67241866182422
# -19.509432057021723 -25.993275040543168 80.38364505409636 28.754920226240905
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_68': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_69': <__main__.Particula object at 0x00000241EC5A5760>}
# 49.603076562571715 -35.64921189033081 29.459654179494766 76.46784423582092
# -19.509432057021723 -25.993275040543168 80.38364505409636 28.754920226240905
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_70': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_71': <__main__.Particula object at 0x00000241EC5A5760>}
# 38.534540092978375 -36.21851832316354 47.06868947202963 77.37355901532757
# -19.50943205702174 -25.993275040543182 80.38364505409638 28.75492022624092
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_72': <__main__.Particula object at 0x00000241EDB20100>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_73': <__main__.Particula object at 0x00000241EDB20280>}
# 31.05195274841089 -35.000920749801914 58.97280570202335 75.4364719667977
# -19.509432057021726 -25.993275040543153 80.38364505409635 28.7549202262409
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_74': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_75': <__main__.Particula object at 0x00000241EC5A5F70>}
# 25.87457626626913 -33.345392073305796 67.20954101452158 72.80267634509933
# -19.509432057021712 -25.993275040543125 80.38364505409635 28.75492022624089
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_76': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_77': <__main__.Particula object at 0x00000241EC5A5F70>}
# 22.16441008796661 -31.699568484351424 73.11207811636653 70.18432063539922
# -19.509432057021698 -25.993275040543097 80.38364505409635 28.75492022624089
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_78': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_79': <__main__.Particula object at 0x00000241EC5A5F70>}
# 19.41326467057916 -30.198972339406367 77.48890037130111 67.79700858662301
# -19.509432057021698 -25.993275040543097 80.38364505409635 28.75492022624089
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_80': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_81': <__main__.Particula object at 0x00000241EC5A5F70>}
# 17.31072671987458 -28.87119464303302 80.83384711105839 65.6846349787563
# -19.509432057021698 -25.993275040543097 80.38364505409635 28.75492022624089
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_82': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_83': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_84': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_85': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_86': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_87': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_88': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_89': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_90': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_91': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_92': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_93': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_94': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_95': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_96': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_97': <__main__.Particula object at 0x00000241EC5A5F70>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_98': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_99': <__main__.Particula object at 0x00000241EC5A5880>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_100': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_101': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_102': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_103': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_104': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_105': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_106': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_107': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_108': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_109': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_110': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_111': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_112': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_113': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_114': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_115': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_116': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_117': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_118': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_119': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_120': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_121': <__main__.Particula object at 0x00000241EC5A5CA0>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_122': <__main__.Particula object at 0x00000241EC5A5670>}
# old_new_particles: {'Cl_1': <__main__.Particula object at 0x00000241EC5A5160>, 'Na_2': <__main__.Particula object at 0x00000241EDB7BE50>}
# new_new_particles: {'NaCl_123': <__main__.Particula object at 0x00000241EC5A5CA0>}
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
#Debugging 03-10-2023
#UI == pygame
#Implementado gráfico Max-Boltz
#Testar colisão por grid - logic
#Colisões e previsão funcionam + grid (inherited 6.10)
#Colisão inelástica e elástica implementada
#Colisão 'no future' mantida por causa de stuttering no pygame
#Colisão futura implementada em classe Particula
#Fazer: reação química


import math
import random
import warnings
import pygame
from pygame.locals import *
from sys import exit
import numpy as np
import matplotlib.pyplot as plt

# Constants
FPS = 60
DT = 1/FPS
ALTURA_CAIXA = 500
LARGURA_CAIXA = 500
NUM_PARTICULAS = 2
GRID_SIZE = 10
FUTURE_FACTOR = 2
TIPO_COLISAO = 'elastic'
COEFICIENTE_RESTITUICAO = 0.0 #coeficiente de restituição

# Indexes de moléculas das reações
NA_CL_INDEX = 0

# Colors
WHITE = (255, 255, 255)

class Particula:
    def __init__(self, p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor):
        self.p_type = p_type
        self.massa = float(massa)
        self.raio = float(raio)
        self.vel_x = float(vel_x)
        self.vel_y = float(vel_y)
        self.x = float(x)
        self.y = float(y)
        self.x_future = float(x_future)
        self.y_future = float(y_future)
        self.cor = cor

    def deslocar(self):

        self.x += self.vel_x * DT
        self.y += self.vel_y * DT

        # Colisao parede
        if self.x < self.raio or self.x > LARGURA_CAIXA - self.raio:
            self.vel_x *= -1
        if self.y < self.raio or self.y > ALTURA_CAIXA - self.raio:
            self.vel_y *= -1

    def next_position(self):
        self.x_future = self.x + self.vel_x * DT * FUTURE_FACTOR
        self.y_future = self.y + self.vel_y * DT * FUTURE_FACTOR

class Grid:
    def __init__(self, width, height, cell_size):
        self.width = width
        self.height = height
        self.cell_size = cell_size
        self.num_cols = int(width / cell_size)
        self.num_rows = int(height / cell_size)
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #cria uma grid nova

    def clear(self):
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #'limpa' a grid

    def index(self, x, y):
        col = int(x / self.cell_size)
        row = int(y / self.cell_size)
        
        # Ensure col and row are within bounds
        col = max(0, min(col, self.num_cols - 1))
        row = max(0, min(row, self.num_rows - 1))
        
        return col + row * self.num_cols

    def insert(self, particle):
        index = self.index(particle.x, particle.y)
        self.grid[index].append(particle)

    def get_particles_in_cell(self, x, y):
        index = self.index(x, y)
        return self.grid[index]

    def update_grid(self, particles):
        self.clear()
        for particle in particles.values():
            self.insert(particle)

    def check_grid_collision(self, particles, grid):
        for particle in particles.values():
            cell_x = int(particle.x / grid.cell_size)
            cell_y = int(particle.y / grid.cell_size)

            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    neighbor_x = cell_x + dx
                    neighbor_y = cell_y + dy
                    if 0 <= neighbor_x < grid.num_cols and 0 <= neighbor_y < grid.num_rows:
                        for neighbor in grid.get_particles_in_cell(neighbor_x * grid.cell_size, neighbor_y * grid.cell_size):
                            if particle != neighbor and check_collision(particle, neighbor):
                                #print(f"Collision detected between {particle} and {neighbor}")
                                resolve_collision(particle, neighbor, collision_type=TIPO_COLISAO)

def check_collision(p1, p2):

    p1.next_position() #proxima_posicao

    p2.next_position() #proxima_posicao

    distance_future = math.sqrt((p2.x_future - p1.x_future)**2 + (p2.y_future - p1.y_future)**2)
    distance = math.sqrt((p2.x - p1.x)**2 + (p2.y - p1.y)**2)
    if ((distance <= p1.raio + p2.raio) or (distance_future <= p1.raio + p2.raio)) == True:
        return True
    else:
        return False


def reaction_collision(particles, p1, p1_index, p2, p2_index, sprites):

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    vel_new_particle = ((p1.massa * v1) + (p2.massa * v2)) / (p1.massa + p2.massa) #apenas momento conservado

    #print('arrays_reaction_v:', v1, v2)

    CM_x = (p1.massa * p1.x + p2.massa * p2.x) / (p1.massa + p2.massa)
    CM_y = (p1.massa * p1.y + p2.massa * p2.y) / (p1.massa + p2.massa)

    #print('arrays_reaction_CM:', CM_x, CM_y )

    new_particles = particles.copy()
    print('old_new_particles:', new_particles)
    #print(p1.p_type, p2.p_type)

    if (p1.p_type == 'Na' and p2.p_type == 'Cl') or (p1.p_type == 'Cl' and p2.p_type == 'Na'):
        #print(p1.p_type, p2.p_type, 'form NaCl')

        global NA_CL_INDEX

        p_type = 'NaCl'
        massa = (p1.massa + p2.massa)
        raio = massa
        vel_x = vel_new_particle[0]
        vel_y = vel_new_particle[1]
        x = CM_x
        y = CM_y
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = (125, 125, 125)
        nome_particula = f"{p_type}_{NA_CL_INDEX}" 
        particle_instance = Particula(p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        NA_CL_INDEX += 1

        new_particles.update({nome_particula : particle_instance})
        remove_particle(particles, sprites, p1_index)
        remove_particle(particles, sprites, p2_index)


    else:
        #print('does not react')
        resolve_collision(p1,p2,collision_type=TIPO_COLISAO)

    print('new_new_particles:',new_particles)
    return new_particles


def remove_particle(particles, sprites, particle_name):
    if particle_name in particles:
        del particles[particle_name]

    for sprite in sprites.sprites():
        if particle_name in sprite.image.get_name():
            sprites.remove(sprite)


def resolve_collision(p1, p2, collision_type='elastic'):
    x1 = np.array([p1.x, p1.y])
    x2 = np.array([p2.x, p2.y])

    #print('arrays_x:', x1, x2)

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    #print('arrays_v:', v1, v2)

    if collision_type == 'elastic' or collision_type == 'elastica':
        #print('elastica')

        C = 1

    if collision_type == 'partial_inelastic' or collision_type == 'parcial_inelastica':
        #print('inelastica')

        C = COEFICIENTE_RESTITUICAO

    new_v1 = v1 - ((((C * p2.massa) + p2.massa) / (p1.massa + p2.massa)) * ((np.dot((v1 - v2),(x1 - x2))) / ((np.linalg.norm(x1 - x2))**2)) * (x1 - x2))
    new_v2 = v2 - ((((C * p1.massa) + p1.massa) / (p1.massa + p2.massa)) * ((np.dot((v2 - v1),(x2 - x1))) / ((np.linalg.norm(x2 - x1))**2)) * (x2 - x1))

    p1.vel_x = new_v1[0]
    p1.vel_y = new_v1[1]
    p2.vel_x = new_v2[0]
    p2.vel_y = new_v2[1]

    print(p1.vel_x, p1.vel_y, p2.vel_x, p2.vel_y)

#src_elastica = https://en.wikipedia.org/wiki/Elastic_collision#Two-dimensional_collision_with_two_moving_objects
#src_inelastica = https://physics.stackexchange.com/questions/708495/angle-free-two-dimensional-inelastic-collision-formula

def iterar_reaction(particles, sprites):
    for particle_name, particle_instance in particles.items():
            for other_particle_name, other_particle_instance in particles.items():
                if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                    #print(f"Collision detected between {particle_name} and {other_particle_name}")
                    new_particles = reaction_collision(particles,particle_instance,particle_name,other_particle_instance,other_particle_name, sprites)
                    iterar_reaction(new_particles)


def gerar_particula(n_particulas):
    particulas = {}

    #atomos
    atomos = {
        "Na": {"massa": 22, "raio": 22, "color": (255, 0, 0)},
        "Cl": {"massa": 35, "raio": 35, "color": (0, 255, 0)},

    }

    for particle_index in range(1, n_particulas + 1):
        #escolha de distribuição aleatória
        atomos_selecionar = random.choice(list(atomos.keys()))

        attributes = atomos[atomos_selecionar]

        p_type = atomos_selecionar
        massa = attributes["massa"]
        raio = attributes["raio"]
        vel_x = random.uniform(-100, 100) #velocidade inicial não especificada
        vel_y = random.uniform(-100, 100)
        x = random.uniform(raio, LARGURA_CAIXA - raio)
        y = random.uniform(raio, ALTURA_CAIXA - raio)
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = attributes["color"]
        nome_particula = f"{atomos_selecionar}_{particle_index}" 
        particle_instance = Particula(p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        particulas[nome_particula] = particle_instance

    return particulas


def intersection_pos_checker(particles,iteration_max = 100):
    iteration_count = 0
    intersection = False
    for particle_name, particle_instance in particles.items():
        for other_particle_name, other_particle_instance in particles.items():
            if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                particle_move = random.choice([[particle_name,particle_instance], [other_particle_name,other_particle_instance]])
                new_x = random.uniform(particle_move[1].raio, LARGURA_CAIXA - (particle_move[1].raio))
                new_y = random.uniform(particle_move[1].raio, ALTURA_CAIXA - (particle_move[1].raio))
                particles[particle_move[0]].x = new_x
                particles[particle_move[0]].y = new_y
                iteration_count +=1
                #print(particles[particle_move[0]].y) #verificar coordenadas alteradas

                intersection = True
                if iteration_max == iteration_count:
                    warnings.warn(f'{iteration_max} iterações atingidas. Deve haver partículas sobrepostas. Altere o tamanho da caixa.')
                    return particles
    
    if intersection == True:
        #print('True')
        return intersection_pos_checker(particles)

    if intersection == False:
        #print('False')
        return particles

def create_particle_sprites(particles):
    sprites = pygame.sprite.Group()
    for particle_instance in particles.values():
        circle = pygame.Surface((particle_instance.raio * 2, particle_instance.raio * 2), pygame.SRCALPHA)
        pygame.draw.circle(circle, particle_instance.cor, (particle_instance.raio, particle_instance.raio), particle_instance.raio)
        sprite = pygame.sprite.Sprite()
        sprite.image = circle
        sprite.rect = sprite.image.get_rect(center=(particle_instance.x, particle_instance.y))
        sprites.add(sprite)
    print(sprites)
    return sprites


def main():
    final_speeds = []
    pygame.init()
    screen = pygame.display.set_mode((LARGURA_CAIXA, ALTURA_CAIXA))
    pygame.display.set_caption("Collision Simulation")

    particles = gerar_particula(NUM_PARTICULAS)
    particles = intersection_pos_checker(particles)
    sprites = create_particle_sprites(particles)

    grid = Grid(LARGURA_CAIXA, ALTURA_CAIXA, GRID_SIZE)

    clock = pygame.time.Clock()


    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                # Pegar velocidades finais de todas as particulas
                for particle_instance in particles.values():
                    final_speed = math.sqrt(particle_instance.vel_x**2 + particle_instance.vel_y**2)
                    final_speeds.append(final_speed)

                # Barplot/histograma das velocidades Max-Boltz.
                fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
                plt.hist(final_speeds, bins=25, color='blue', edgecolor='black', alpha=0.7)
                plt.xlabel('Velocidade')
                plt.ylabel('Frequência')
                plt.title('Histograma das velocidades finais')
                plt.grid(True)
                fig.tight_layout()
                fig.savefig("max-boltz_6_11.png")  # Salva a figura

                plt.show()
                exit()

        # Update the grid with the new particle positions
        grid.update_grid(particles)

        # Check for collisions based on the updated grid
        grid.check_grid_collision(particles, grid)

        # Reação
        iterar_reaction(particles, sprites)

        # Update particle positions after collision detection
        for particle_name, particle_instance in particles.items():
            particle_instance.deslocar()

        # Update sprite positions
        for sprite, particle_instance in zip(sprites, particles.values()):
            sprite.rect.center = (particle_instance.x, particle_instance.y)

        screen.fill(WHITE)
        sprites.draw(screen)

        pygame.display.flip()
        clock.tick(FPS)

if __name__ == "__main__":
    main()
# Out:
# <Group(2 sprites)>
# old_new_particles: {'Na_1': <__main__.Particula object at 0x00000241EC77CCD0>, 'Cl_2': <__main__.Particula object at 0x00000241EC952250>}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 366
#     363         clock.tick(FPS)
#     365 if __name__ == "__main__":
# --> 366     main()
#
# Cell In[8], line 349, in main()
#     346 grid.check_grid_collision(particles, grid)
#     348 # Reação
# --> 349 iterar_reaction(particles, sprites)
#     351 # Update particle positions after collision detection
#     352 for particle_name, particle_instance in particles.items():
#
# Cell In[8], line 228, in iterar_reaction(particles, sprites)
#     225 for other_particle_name, other_particle_instance in particles.items():
#     226     if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
#     227         #print(f"Collision detected between {particle_name} and {other_particle_name}")
# --> 228         new_particles = reaction_collision(particles,particle_instance,particle_name,other_particle_instance,other_particle_name, sprites)
#     229         iterar_reaction(new_particles)
#
# Cell In[8], line 168, in reaction_collision(particles, p1, p1_index, p2, p2_index, sprites)
#     165     NA_CL_INDEX += 1
#     167     new_particles.update({nome_particula : particle_instance})
# --> 168     remove_particle(particles, sprites, p1_index)
#     169     remove_particle(particles, sprites, p2_index)
#     172 else:
#     173     #print('does not react')
#
# Cell In[8], line 185, in remove_particle(particles, sprites, particle_name)
#     182     del particles[particle_name]
#     184 for sprite in sprites.sprites():
# --> 185     if particle_name in sprite.image.get_name():
#     186         sprites.remove(sprite)
#
# AttributeError: 'pygame.surface.Surface' object has no attribute 'get_name'

# %%
#Debugging 03-10-2023
#UI == pygame
#Implementado gráfico Max-Boltz
#Testar colisão por grid - logic
#Colisões e previsão funcionam + grid (inherited 6.10)
#Colisão inelástica e elástica implementada
#Colisão 'no future' mantida por causa de stuttering no pygame
#Colisão futura implementada em classe Particula
#Fazer: reação química


import math
import random
import warnings
import pygame
from pygame.locals import *
from sys import exit
import numpy as np
import matplotlib.pyplot as plt

# Constants
FPS = 60
DT = 1/FPS
ALTURA_CAIXA = 500
LARGURA_CAIXA = 500
NUM_PARTICULAS = 2
GRID_SIZE = 10
FUTURE_FACTOR = 2
TIPO_COLISAO = 'elastic'
COEFICIENTE_RESTITUICAO = 0.0 #coeficiente de restituição

# Indexes de moléculas das reações
NA_CL_INDEX = 0

# Colors
WHITE = (255, 255, 255)

class Particula:
    def __init__(self, p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor):
        self.p_type = p_type
        self.massa = float(massa)
        self.raio = float(raio)
        self.vel_x = float(vel_x)
        self.vel_y = float(vel_y)
        self.x = float(x)
        self.y = float(y)
        self.x_future = float(x_future)
        self.y_future = float(y_future)
        self.cor = cor

    def deslocar(self):

        self.x += self.vel_x * DT
        self.y += self.vel_y * DT

        # Colisao parede
        if self.x < self.raio or self.x > LARGURA_CAIXA - self.raio:
            self.vel_x *= -1
        if self.y < self.raio or self.y > ALTURA_CAIXA - self.raio:
            self.vel_y *= -1

    def next_position(self):
        self.x_future = self.x + self.vel_x * DT * FUTURE_FACTOR
        self.y_future = self.y + self.vel_y * DT * FUTURE_FACTOR

class Grid:
    def __init__(self, width, height, cell_size):
        self.width = width
        self.height = height
        self.cell_size = cell_size
        self.num_cols = int(width / cell_size)
        self.num_rows = int(height / cell_size)
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #cria uma grid nova

    def clear(self):
        self.grid = [[] for _ in range(self.num_cols * self.num_rows)] #'limpa' a grid

    def index(self, x, y):
        col = int(x / self.cell_size)
        row = int(y / self.cell_size)
        
        # Ensure col and row are within bounds
        col = max(0, min(col, self.num_cols - 1))
        row = max(0, min(row, self.num_rows - 1))
        
        return col + row * self.num_cols

    def insert(self, particle):
        index = self.index(particle.x, particle.y)
        self.grid[index].append(particle)

    def get_particles_in_cell(self, x, y):
        index = self.index(x, y)
        return self.grid[index]

    def update_grid(self, particles):
        self.clear()
        for particle in particles.values():
            self.insert(particle)

    def check_grid_collision(self, particles, grid):
        for particle in particles.values():
            cell_x = int(particle.x / grid.cell_size)
            cell_y = int(particle.y / grid.cell_size)

            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    neighbor_x = cell_x + dx
                    neighbor_y = cell_y + dy
                    if 0 <= neighbor_x < grid.num_cols and 0 <= neighbor_y < grid.num_rows:
                        for neighbor in grid.get_particles_in_cell(neighbor_x * grid.cell_size, neighbor_y * grid.cell_size):
                            if particle != neighbor and check_collision(particle, neighbor):
                                #print(f"Collision detected between {particle} and {neighbor}")
                                resolve_collision(particle, neighbor, collision_type=TIPO_COLISAO)

def check_collision(p1, p2):

    p1.next_position() #proxima_posicao

    p2.next_position() #proxima_posicao

    distance_future = math.sqrt((p2.x_future - p1.x_future)**2 + (p2.y_future - p1.y_future)**2)
    distance = math.sqrt((p2.x - p1.x)**2 + (p2.y - p1.y)**2)
    if ((distance <= p1.raio + p2.raio) or (distance_future <= p1.raio + p2.raio)) == True:
        return True
    else:
        return False


def reaction_collision(particles, p1, p1_index, p2, p2_index):

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    vel_new_particle = ((p1.massa * v1) + (p2.massa * v2)) / (p1.massa + p2.massa) #apenas momento conservado

    #print('arrays_reaction_v:', v1, v2)

    CM_x = (p1.massa * p1.x + p2.massa * p2.x) / (p1.massa + p2.massa)
    CM_y = (p1.massa * p1.y + p2.massa * p2.y) / (p1.massa + p2.massa)

    #print('arrays_reaction_CM:', CM_x, CM_y )

    new_particles = particles.copy()
    print('old_new_particles:', new_particles)
    #print(p1.p_type, p2.p_type)

    if (p1.p_type == 'Na' and p2.p_type == 'Cl') or (p1.p_type == 'Cl' and p2.p_type == 'Na'):
        #print(p1.p_type, p2.p_type, 'form NaCl')

        global NA_CL_INDEX

        p_type = 'NaCl'
        massa = (p1.massa + p2.massa)
        raio = massa
        vel_x = vel_new_particle[0]
        vel_y = vel_new_particle[1]
        x = CM_x
        y = CM_y
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = (125, 125, 125)
        nome_particula = f"{p_type}_{NA_CL_INDEX}" 
        particle_instance = Particula(p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        NA_CL_INDEX += 1

        new_particles.update({nome_particula : particle_instance})
        new_particles.pop(p1_index)
        new_particles.pop(p2_index)


    else:
        #print('does not react')
        resolve_collision(p1,p2,collision_type=TIPO_COLISAO)

    print('new_new_particles:',new_particles)
    return new_particles


def resolve_collision(p1, p2, collision_type='elastic'):
    x1 = np.array([p1.x, p1.y])
    x2 = np.array([p2.x, p2.y])

    #print('arrays_x:', x1, x2)

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    #print('arrays_v:', v1, v2)

    if collision_type == 'elastic' or collision_type == 'elastica':
        #print('elastica')

        C = 1

    if collision_type == 'partial_inelastic' or collision_type == 'parcial_inelastica':
        #print('inelastica')

        C = COEFICIENTE_RESTITUICAO

    new_v1 = v1 - ((((C * p2.massa) + p2.massa) / (p1.massa + p2.massa)) * ((np.dot((v1 - v2),(x1 - x2))) / ((np.linalg.norm(x1 - x2))**2)) * (x1 - x2))
    new_v2 = v2 - ((((C * p1.massa) + p1.massa) / (p1.massa + p2.massa)) * ((np.dot((v2 - v1),(x2 - x1))) / ((np.linalg.norm(x2 - x1))**2)) * (x2 - x1))

    p1.vel_x = new_v1[0]
    p1.vel_y = new_v1[1]
    p2.vel_x = new_v2[0]
    p2.vel_y = new_v2[1]

    print(p1.vel_x, p1.vel_y, p2.vel_x, p2.vel_y)

#src_elastica = https://en.wikipedia.org/wiki/Elastic_collision#Two-dimensional_collision_with_two_moving_objects
#src_inelastica = https://physics.stackexchange.com/questions/708495/angle-free-two-dimensional-inelastic-collision-formula

def iterar_reaction(particles):
    for particle_name, particle_instance in particles.items():
            for other_particle_name, other_particle_instance in particles.items():
                if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                    #print(f"Collision detected between {particle_name} and {other_particle_name}")
                    new_particles = reaction_collision(particles,particle_instance,particle_name,other_particle_instance,other_particle_name)
                    iterar_reaction(new_particles)


def gerar_particula(n_particulas):
    particulas = {}

    #atomos
    atomos = {
        "Na": {"massa": 22, "raio": 22, "color": (255, 0, 0)},
        "Cl": {"massa": 35, "raio": 35, "color": (0, 255, 0)},

    }

    for particle_index in range(1, n_particulas + 1):
        #escolha de distribuição aleatória
        atomos_selecionar = random.choice(list(atomos.keys()))

        attributes = atomos[atomos_selecionar]

        p_type = atomos_selecionar
        massa = attributes["massa"]
        raio = attributes["raio"]
        vel_x = random.uniform(-100, 100) #velocidade inicial não especificada
        vel_y = random.uniform(-100, 100)
        x = random.uniform(raio, LARGURA_CAIXA - raio)
        y = random.uniform(raio, ALTURA_CAIXA - raio)
        x_future = x + vel_x * DT * FUTURE_FACTOR
        y_future = y + vel_y * DT * FUTURE_FACTOR
        cor = attributes["color"]
        nome_particula = f"{atomos_selecionar}_{particle_index}" 
        particle_instance = Particula(p_type, massa, raio, vel_x, vel_y, x, y, x_future, y_future, cor)
        particulas[nome_particula] = particle_instance

    return particulas


def intersection_pos_checker(particles,iteration_max = 100):
    iteration_count = 0
    intersection = False
    for particle_name, particle_instance in particles.items():
        for other_particle_name, other_particle_instance in particles.items():
            if particle_name != other_particle_name and check_collision(particle_instance, other_particle_instance):
                particle_move = random.choice([[particle_name,particle_instance], [other_particle_name,other_particle_instance]])
                new_x = random.uniform(particle_move[1].raio, LARGURA_CAIXA - (particle_move[1].raio))
                new_y = random.uniform(particle_move[1].raio, ALTURA_CAIXA - (particle_move[1].raio))
                particles[particle_move[0]].x = new_x
                particles[particle_move[0]].y = new_y
                iteration_count +=1
                #print(particles[particle_move[0]].y) #verificar coordenadas alteradas

                intersection = True
                if iteration_max == iteration_count:
                    warnings.warn(f'{iteration_max} iterações atingidas. Deve haver partículas sobrepostas. Altere o tamanho da caixa.')
                    return particles
    
    if intersection == True:
        #print('True')
        return intersection_pos_checker(particles)

    if intersection == False:
        #print('False')
        return particles

def create_particle_sprites(particles):
    sprites = pygame.sprite.Group()
    for particle_instance in particles.values():
        circle = pygame.Surface((particle_instance.raio * 2, particle_instance.raio * 2), pygame.SRCALPHA)
        pygame.draw.circle(circle, particle_instance.cor, (particle_instance.raio, particle_instance.raio), particle_instance.raio)
        sprite = pygame.sprite.Sprite()
        sprite.image = circle
        sprite.rect = sprite.image.get_rect(center=(particle_instance.x, particle_instance.y))
        sprites.add(sprite)
    print(sprites)
    return sprites


def main():
    final_speeds = []
    pygame.init()
    screen = pygame.display.set_mode((LARGURA_CAIXA, ALTURA_CAIXA))
    pygame.display.set_caption("Collision Simulation")

    particles = gerar_particula(NUM_PARTICULAS)
    particles = intersection_pos_checker(particles)
    sprites = create_particle_sprites(particles)

    grid = Grid(LARGURA_CAIXA, ALTURA_CAIXA, GRID_SIZE)

    clock = pygame.time.Clock()

    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                for particle_instance in particles.values():
                    final_speed = math.sqrt(particle_instance.vel_x ** 2 + particle_instance.vel_y ** 2)
                    final_speeds.append(final_speed)

                fig, ax = plt.subplots(figsize=(6, 6))
                plt.hist(final_speeds, bins=25, color='blue', edgecolor='black', alpha=0.7)
                plt.xlabel('Velocidade')
                plt.ylabel('Frequência')
                plt.title('Histograma das velocidades finais')
                plt.grid(True)
                fig.tight_layout()
                fig.savefig("max-boltz_6_11.png")
                plt.show()
                exit()

        grid.update_grid(particles)
        grid.check_grid_collision(particles, grid)
        iterar_reaction(particles)

        for particle_name, particle_instance in particles.items():
            particle_instance.deslocar()

        for sprite, particle_instance in zip(sprites, particles.values()):
            sprite.rect.center = (particle_instance.x, particle_instance.y)

        # Remove a particle and its sprite based on some condition
        if should_remove_particle_condition:
            particle_name_to_remove = "Na_1"  # Replace with the name of the particle you want to remove
            if particle_name_to_remove in particles:
                del particles[particle_name_to_remove]
                for sprite in sprites:
                    if particle_name_to_remove in sprite.image.get_name():
                        sprite.kill()

        screen.fill(WHITE)
        sprites.draw(screen)

        pygame.display.flip()
        clock.tick(FPS)


if __name__ == "__main__":
    main()
# Out:
# <Group(2 sprites)>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 356
#     352         clock.tick(FPS)
#     355 if __name__ == "__main__":
# --> 356     main()
#
# Cell In[6], line 340, in main()
#     337     sprite.rect.center = (particle_instance.x, particle_instance.y)
#     339 # Remove a particle and its sprite based on some condition
# --> 340 if should_remove_particle_condition:
#     341     particle_name_to_remove = "Na_1"  # Replace with the name of the particle you want to remove
#     342     if particle_name_to_remove in particles:
#
# NameError: name 'should_remove_particle_condition' is not defined
