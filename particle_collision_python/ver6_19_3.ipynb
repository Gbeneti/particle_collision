# %%
#Debugging 14-11-2023 == FALSE_V1; LATEST STABLE == V1
#UI == pygame
#Implementado gráfico Max-Boltz
#Implementação do fit da Lei de Velocidade
#'future' funciona (inherited 6_10)
#Colisão inelástica e elástica implementada
#Colisão futura implementada em classe Particul
#Reação química feita + grafico conc./tempo
#Fazer: encontrar a lei de velocidade (derivadas)
#Problemas: 
# -não é vetorializado
# -baixa eficiência por itertools
# -NA_CL_INDEX como global
# -a = 'Na', b = 'Cl'; a = 'Cl', b = 'Na'-> e se forem 3?
# -intersection_position_checker que nao precisa checar tudo ?
# -reações que geram partículas grandes podem gerar intersecção com outra que está indo em direção a esta

# Catálise homogênea e heterogênea - ver sobre
# Adição do catalisador como parede -> vel == 0 True
# O código é sobre heterogenea
# Adicionado 'states' para entender quais colisões e reações

#Vetorialização:
#Usar arrays; mínimo de for's e while's (loops); numpy; scipy cdist; numpy.greater

import random
import warnings
import pygame
from pygame.locals import *
from sys import exit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lmfit.models import ExponentialModel, LinearModel
from lmfit import Model, Parameters
import itertools

# VERSION
VERSION = '6_19_3'

# Constants
FPS = 60
DT = 1/FPS
ALTURA_CAIXA = 500
LARGURA_CAIXA = 500
NUM_PARTICULAS = 100
#GRID_SIZE = 10
FUTURE_FACTOR = 1.5
TIPO_COLISAO = 'elastic'
COEFICIENTE_RESTITUICAO = 0.0 #coeficiente de restituição

AVOGADRO_CONSTANT = 6.022e23 #constante de avogadro
BOLTZMANN_CONSTANT = 1.380649e-23 #m2 kg s-2 K-1

MASSA_PROTON = 1.67262192e-27 #em Kg
MASSA_NEUTRON = 1.65e-27 #em Kg

NAME_BOLTZ = f'max-boltz_{VERSION}.png'
NAME_CONCENTRATION_PLOT = f'concentration_{VERSION}.png'
NAME_INTEGRATION_RATE_LAW_PLOT = f'inverse_concentration_{VERSION}.png'
NAME_FIT_CONCENTRATION_PLOT = f'fit_concentration_{VERSION}.png'
NAME_VEL_RATE = f'velocidade_reacao_{VERSION}.png'
NAME_CHEMICAL_CSV = f'df_chemical_data_{VERSION}.csv'
NAME_MOLARITY_CSV = f'df_molarity_data_{VERSION}.csv'

# Indexes de moléculas das reações
NA_CL_INDEX = 0
CHANCE_NACL_GLOBAL = 0.4 #chances de não acontecer a reação

# Colors
WHITE = (255, 255, 255)

class Particula:
    def __init__(self, p_type, state, massa, raio, vel_x, vel_y, x, y, chance_reaction,cor):
        self.p_type = p_type
        self.state = state
        self.massa = float(massa)
        self.raio = float(raio)
        self.vel_x = float(vel_x)
        self.vel_y = float(vel_y)
        self.x = float(x)
        self.y = float(y)
        self.x_future = None
        self.y_future = None
        self.chance_reaction = chance_reaction
        self.cor = cor
        self.sprite_pygame = self.sprite_pygame()

    def deslocar(self):

        self.x += self.vel_x * DT
        self.y += self.vel_y * DT

    def next_position(self):
        self.x_future = self.x + self.vel_x * DT * FUTURE_FACTOR
        self.y_future = self.y + self.vel_y * DT * FUTURE_FACTOR

        if self.x_future < self.raio or self.x_future > LARGURA_CAIXA - self.raio:
            if self.p_type == "Na":
                self.state = 'fixed'
                self.vel_x = 0.0
                self.vel_y = 0.0
                self.chance_reaction = 1.0
            else:    
                self.vel_x *= -1
            #print("ativada por x")
        if self.y_future < self.raio or self.y_future > ALTURA_CAIXA - self.raio:
            if self.p_type == "Na":
                self.state = 'fixed'
                self.vel_x = 0.0
                self.vel_y = 0.0
                self.chance_reaction = 1.0
            else:
                self.vel_y *= -1
            #print("ativada por y")

        #print('next_position')

    def sprite_pygame(self):
        circle = pygame.Surface((self.raio * 2, self.raio * 2), pygame.SRCALPHA)
        pygame.draw.circle(circle, self.cor, (self.raio, self.raio), self.raio)
        sprite = pygame.sprite.Sprite()
        sprite.image = circle
        sprite.rect = sprite.image.get_rect(center=(self.x, self.y))
        return sprite

def check_collision(p1, p2):

    p1.next_position() #proxima_posicao

    p2.next_position() #proxima_posicao

    distance_future = np.sqrt((p2.x_future - p1.x_future)**2 + (p2.y_future - p1.y_future)**2)
    #distance = np.sqrt((p2.x - p1.x)**2 + (p2.y - p1.y)**2)
    if (distance_future <= p1.raio + p2.raio) == True:
        return True
    else:
        return False


def reaction_collision(particles, p1, p1_index, p2, p2_index, sprites):

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    vel_new_particle = ((p1.massa * v1) + (p2.massa * v2)) / (p1.massa + p2.massa) #apenas momento conservado

    #print('arrays_reaction_v:', v1, v2)

    CM_x = (p1.massa * p1.x + p2.massa * p2.x) / (p1.massa + p2.massa)
    CM_y = (p1.massa * p1.y + p2.massa * p2.y) / (p1.massa + p2.massa)

    p1_chance = p1.chance_reaction #chance de acontecer a reação
    p2_chance = p2.chance_reaction

    #print('arrays_reaction_CM:', CM_x, CM_y )

    #new_particles = particles.copy()
    #print('old_particles:', particles)


    if ((p1.p_type == 'Na' and p2.p_type == 'Cl') or (p1.p_type == 'Cl' and p2.p_type == 'Na')) and (p1_chance > CHANCE_NACL_GLOBAL or p2_chance > CHANCE_NACL_GLOBAL):
        #print(p1.p_type, p2.p_type, 'form NaCl')

        global NA_CL_INDEX

        p_type = 'NaCl'
        state = 'mobile'
        massa = (p1.massa + p2.massa)
        raio = 5
        vel_x = vel_new_particle[0]
        vel_y = vel_new_particle[1]
        x = CM_x
        y = CM_y
        #x_future = x + vel_x * DT * FUTURE_FACTOR
        #y_future = y + vel_y * DT * FUTURE_FACTOR
        chance_reaction = 0.00005
        cor = (125, 125, 125)
        nome_particula = f"{p_type}_{NA_CL_INDEX}" 
        particle_instance = Particula(p_type, state, massa,raio, vel_x, vel_y, x, y, chance_reaction,cor)

        sprites.add(particle_instance.sprite_pygame)
        
        NA_CL_INDEX += 1

        particles.update({nome_particula : particle_instance})

        print("Before deletion:", particles.keys())
        print(f"Deleting particles with indices: {p1_index}, {p2_index}")

        del particles[p1_index]
        del particles[p2_index]

        print("After deletion:", particles.keys())

        p1.sprite_pygame.kill()
        p2.sprite_pygame.kill()

        return particles

    if p1.state == 'mobile' and p2.state == 'mobile':
        resolve_collision(p1,p2,collision_type=TIPO_COLISAO)
        return particles

    if ((p1.p_type == 'Na' and p2.p_type == 'NaCl') or (p1.p_type == 'NaCl' and p2.p_type == 'Na')):
        #print('Na + NaCl')

        if p2.state == 'fixed':
            p1.vel_x *= -1
            p1.vel_y *= -1

        if p1.state == 'fixed':
            p2.vel_x *= -1
            p2.vel_y *= -1

        return particles


    if ((p1.p_type == 'Na' and p2.p_type == 'Na') or (p1.p_type == 'Na' and p2.p_type == 'Na')):

        if p2.state == 'fixed':
            p1.vel_x *= -1
            p2.vel_y *= -1

        if p1.state == 'fixed':
            p2.vel_x *= -1
            p2.vel_y *= -1

        return particles

    else:
        #print('does not react')
        #print('collision solved')
        resolve_collision(p1,p2,collision_type=TIPO_COLISAO)
        return particles

    #print('new_particles:',particles)
    #print()

    #return particles
    #return deve ser dado depois de cada if se nn o else roda e resolve a colisão


def resolve_collision(p1, p2, collision_type='elastic'):
    x1 = np.array([p1.x, p1.y])
    x2 = np.array([p2.x, p2.y])

    #print('arrays_x:', x1, x2)

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    #print('arrays_v:', v1, v2)

    if collision_type == 'elastic' or collision_type == 'elastica':
        #print('elastica')

        C = 1

    if collision_type == 'partial_inelastic' or collision_type == 'parcial_inelastica':
        #print('inelastica')

        C = COEFICIENTE_RESTITUICAO

    new_v1 = v1 - ((((C * p2.massa) + p2.massa) / (p1.massa + p2.massa)) * ((np.dot((v1 - v2),(x1 - x2))) / ((np.linalg.norm(x1 - x2))**2)) * (x1 - x2))
    new_v2 = v2 - ((((C * p1.massa) + p1.massa) / (p1.massa + p2.massa)) * ((np.dot((v2 - v1),(x2 - x1))) / ((np.linalg.norm(x2 - x1))**2)) * (x2 - x1))

    p1.vel_x = new_v1[0]
    p1.vel_y = new_v1[1]
    p2.vel_x = new_v2[0]
    p2.vel_y = new_v2[1]

    #print('resolution',p1.vel_x, p1.vel_y, p2.vel_x, p2.vel_y)

#src_elastica = https://en.wikipedia.org/wiki/Elastic_collision#Two-dimensional_collision_with_two_moving_objects
#src_inelastica = https://physics.stackexchange.com/questions/708495/angle-free-two-dimensional-inelastic-collision-formula




def gerar_particula(n_particulas):
    particulas = {}

    #atomos
    atomos = {
        "Na": {"massa": 11*MASSA_PROTON + 12*MASSA_NEUTRON, "raio": 5, "color": (255, 0, 0)}, #approximations
        "Cl": {"massa": 17*MASSA_PROTON + 18*MASSA_NEUTRON, "raio": 5, "color": (0, 255, 0)},
        #"NaCl" : {"massa": 11*MASSA_PROTON + 12*MASSA_NEUTRON + 17*MASSA_PROTON + 18*MASSA_NEUTRON, "raio": 5, "color": (125, 125, 125)} #testes

    }

    for particle_index in range(1, n_particulas + 1):

        #escolha de distribuição aleatória
        atomos_selecionar = random.choice(list(atomos.keys()))

        attributes = atomos[atomos_selecionar]

        p_type = atomos_selecionar
        state = 'mobile'
        massa = attributes["massa"]
        raio = attributes["raio"]
        vel = random.uniform(100,600)
        vel_angle = np.random.uniform(0, 2 * np.pi)
        vel_x = vel * np.cos(vel_angle) #velocidade inicial não especificada
        vel_y = vel * np.sin(vel_angle)
        x = random.uniform(raio, LARGURA_CAIXA - raio)
        y = random.uniform(raio, ALTURA_CAIXA - raio)
        #x_future = x + vel_x * DT * FUTURE_FACTOR
        #y_future = y + vel_y * DT * FUTURE_FACTOR
        chance_reaction = 0.00005
        cor = attributes["color"]
        nome_particula = f"{atomos_selecionar}_{particle_index}" 
        particle_instance = Particula(p_type, state, massa, raio, vel_x, vel_y, x, y, chance_reaction, cor)
        particulas[nome_particula] = particle_instance
        #print(vel_x,vel_y,vel,vel_angle)

    return particulas

def select_particles(particles,sprites):
    particles_update = set()
    particles_remove = []

    #print('entrou pra selected')

    # particle_pairs = np.array(list(itertools.combinations(particles.items(), 2)))
    #print('pares',particle_pairs)

    for (name_p1, instance_p1), (name_p2, instance_p2) in itertools.combinations(particles.items(), 2):
        #print((name_p1, type(instance_p1)), (name_p2, type(instance_p2)))
        if check_collision(instance_p1, instance_p2):
            #print('foi pra reacted')
            reacted_particles = reaction_collision(particles, instance_p1, name_p1, instance_p2, name_p2,sprites)
            

            if particles != reacted_particles:
                particles_update.update(reacted_particles)
                particles_remove.extend([name_p1, name_p2])

    for particle_name in particles_remove:
        del particles[particle_name]

    particles.update(particles_update)

    return particles



def intersection_pos_checker(particles,iteration_max = 100):
    iteration_count = 0
    intersection = False
    #particle_pairs = np.array(list(itertools.permutations(particles.items(), 2)))
    for (name_p1, instance_p1), (name_p2, instance_p2) in itertools.combinations(particles.items(), 2):
        if check_collision(instance_p1, instance_p2):
                particle_move = random.choice([[name_p1,instance_p1], [name_p2,instance_p2]])
                new_x = random.uniform(particle_move[1].raio, LARGURA_CAIXA - (particle_move[1].raio))
                new_y = random.uniform(particle_move[1].raio, ALTURA_CAIXA - (particle_move[1].raio))
                particles[particle_move[0]].x = new_x
                particles[particle_move[0]].y = new_y
                iteration_count +=1
                #print(particles[particle_move[0]].y) #verificar coordenadas alteradas

                intersection = True
                if iteration_max == iteration_count:
                    warnings.warn(f'{iteration_max} iterações atingidas. Deve haver partículas sobrepostas. Altere o tamanho da caixa.')
                    return particles
    
    if intersection == True:
        #print('True')
        return intersection_pos_checker(particles)

    if intersection == False:
        #print('False')
        return particles


def create_particle_group_sprites(particles):
    sprites = pygame.sprite.Group()
    for particle_instance in particles.values():
        sprite = particle_instance.sprite_pygame
        sprites.add(sprite)
    #print(sprites)
    return sprites


def chemical_counter(particles,time_passed,system_temperature,df=pd.DataFrame()):
    chem_list = particles.keys()

    element_count = {}  # Initialize an empty dictionary to store element counts

    for item in chem_list:
        element = item.split('_')[0]  # Extract the element (part before the underscore)
        if element in element_count:
            element_count[element] += 1  # Increment the count if the element already exists
        else:
            element_count[element] = 1  # Initialize count to 1 if the element is encountered for the first time


    chem_array = np.concatenate((np.array([time_passed]),np.array([system_temperature]),np.array(list(element_count.values()))))
    df_chem = pd.DataFrame(chem_array).T
    df_chem.columns = np.concatenate((np.array(['Tempo [s]']),np.array(['Temperatura [K]']),np.array(list(element_count.keys()))))

    df_chem = pd.concat([df, df_chem], axis=0, ignore_index=True)

    return df_chem


def convert_to_molarity(df,liter):
    df_molar = df.copy()
    for column in range(1,df_molar.shape[1]):
        #print(column)
        df_molar.iloc[:,column] = ((df_molar.iloc[:,column]/AVOGADRO_CONSTANT)/liter)
    return df_molar

def determine_temperature(particles): #determina a temperatura baseada na média da vel. quadrada
    # sai de m*<v^2>/2 = 1/2 * 2 kt
    #nesse caso: <m*v**2>/2 = 0.5 * k*T
    array_vel_x = np.array([particle.vel_x for particle in particles.values()])
    array_vel_y = np.array([particle.vel_y for particle in particles.values()])
    array_massa = np.array([particle.massa for particle in particles.values()])

    mass_vel_average = np.mean(array_massa * np.sqrt((array_vel_x**2) + (array_vel_y**2)))
    temperature = mass_vel_average / (2*BOLTZMANN_CONSTANT) #dois graus de liberdade; sai em K

    return temperature

def fit_concentration_plot(df,name,sup_lim=-1):
    x_data = df.iloc[0:sup_lim,0].values

    y1_data = df.iloc[0:sup_lim,1].values #Cl
    y2_data = df.iloc[0:sup_lim,2].values #Na
    #print(len(y1_data),len(y2_data))

    modelo_exponencial_1 = ExponentialModel(prefix = 'exp_1_')
    modelo_exponencial_2 = ExponentialModel(prefix = 'exp_2_')
    print(f'Variável independente_1: {modelo_exponencial_1.independent_vars}')
    print(f'Parâmetros modelo_1: {modelo_exponencial_1.param_names}')
    print()
    print(f'Variável independente_2: {modelo_exponencial_2.independent_vars}')
    print(f'Parâmetros modelo_2: {modelo_exponencial_2.param_names}')

    params_exponencial_1 = modelo_exponencial_1.guess(y1_data,x=x_data)
    params_exponencial_2 = modelo_exponencial_2.guess(y2_data,x=x_data)
    params_exponencial_1.pretty_print()
    print()
    params_exponencial_2.pretty_print()

    resultado_fit_1 = modelo_exponencial_1.fit(y1_data, params_exponencial_1, x=x_data)
    resultado_fit_2 = modelo_exponencial_2.fit(y2_data, params_exponencial_2, x=x_data)
    print(resultado_fit_1.fit_report())
    print()
    print(resultado_fit_2.fit_report())

    fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    ax.plot(x_data, y1_data, label="Data Cl")
    ax.plot(x_data, y2_data, label="Data Na")
    ax.plot(x_data, resultado_fit_1.best_fit, label="Fit Cl")
    ax.plot(x_data, resultado_fit_2.best_fit, label="Fit Na")
    plt.title('Concentração x Tempo')
    plt.xlabel('Tempo [s]')
    plt.ylabel('Concentração [mol/L]')
    plt.legend()
    plt.grid(True)
    fig.tight_layout()
    fig.savefig(name)  # Salva a figura
    plt.show()

    data_vel_fit = {'x_data' : x_data,'resultado_fit_1' : resultado_fit_1, 'resultado_fit_2' : resultado_fit_2, 'y1_data' : y1_data, 'y2_data' : y2_data}

    return data_vel_fit


def vel_rate_plot(data_vel_fit,name):
    #print(data_vel_fit['resultado_fit_1'])
    #print(data_vel_fit['resultado_fit_1'].best_fit)
    derivative = -np.diff(data_vel_fit['resultado_fit_1'].best_fit,n=1)
    #print(derivative)
    concentrations = data_vel_fit['y1_data'][:-1]


    # Define the quadratic model function
    def quadratic_model(x, a, b, c):
        return a * x**2 + b * x + c
        
    mod = Model(quadratic_model)

# Automatically guess initial parameter values
    params_quadratic = Parameters()
    params_quadratic.add('a', value=1.0)
    params_quadratic.add('b', value=1.0)
    params_quadratic.add('c', value=1.0)

    # Perform the fit
    result_quadratic = mod.fit(derivative, params_quadratic, x=concentrations)

    # Print and visualize the fit results
    print(result_quadratic.fit_report())
    a_value = result_quadratic.params['a'].value
    b_value = result_quadratic.params['b'].value
    c_value = result_quadratic.params['c'].value

    fig2, ax2 = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    #ax2.plot(data_vel_fit['y1_data'], derivative_1, label = "Velocidade em Cl")
    ax2.plot(1/concentrations,derivative, label = "Concentração de Cl")
    ax2.plot(1/concentrations, result_quadratic.best_fit, label=f"Coeficiente K: {a_value}", color='red')

    plt.title('Fit d[Concentração]/dt x Concentração')
    plt.xlabel('Concentração')
    plt.ylabel('Velocidade')
    plt.legend()
    plt.grid(True)
    fig2.tight_layout()
    fig2.savefig(name)  # Salva a figura
    plt.show()

def maxwell_boltzmann_plot(final_speeds,name):
    # Barplot/histograma das velocidades Max-Boltz.
    fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    plt.hist(final_speeds, bins=25, color='blue', edgecolor='black', alpha=0.7)
    plt.xlabel('Velocidade [m/s]')
    plt.ylabel('Frequência [un]')
    plt.title('Histograma das velocidades finais')
    plt.grid(True)
    fig.tight_layout()
    fig.savefig(name)  # Salva a figura
    plt.show()

def concentration_plot(df,name):
    # Lineplot das concentrações/tempo.
    fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    for y_axis, labels in zip(df.columns[2:],list(df.columns)[2:]):
        plt.plot(df['Tempo [s]'],(df[y_axis]),alpha=0.7, label=labels)
    plt.legend()
    plt.xlabel('Tempo [s]')
    plt.ylabel('Concentração [mol/L]')
    plt.title('Evolução temporal das concentrações')
    plt.grid(True)
    fig.tight_layout()
    fig.savefig(name)  # Salva a figura
    plt.show()

def integration_rate_law_plot(df,name):
    inverse = (1/df['NaCl']).replace(np.inf,0,inplace=True)
    print('inversa', inverse)
    # Lineplot das concentrações/tempo.
    fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    model = LinearModel()
    params = model.make_params(slope=1, intercept=1)
    result = model.fit(inverse, params, x=df['Tempo [s]'])
    slope = result.params['slope'].value
    intercept = result.params['intercept'].value
    plt.scatter(df['Tempo [s]'], inverse, label='Original Data')
    plt.plot(df['Tempo [s]'], result.best_fit, label='Linear Fit', color='red') 


    #plt.plot(df['Tempo [s]'],(df[y_axis]),alpha=0.7, label=labels)
    plt.legend()
    plt.xlabel('Tempo [s]')
    plt.ylabel('1/[NaCl]')
    plt.title('Evolução temporal da integração da lei de velocidade')
    plt.grid(True)
    fig.tight_layout()
    fig.savefig(name)  # Salva a figura
    plt.show()



def main():
    final_speeds = []
    pygame.init()
    screen = pygame.display.set_mode((LARGURA_CAIXA, ALTURA_CAIXA))
    pygame.display.set_caption("Collision Simulation")

    particles = gerar_particula(NUM_PARTICULAS)
    particles = intersection_pos_checker(particles)
    sprites = create_particle_group_sprites(particles)

    #digito_atual = 0
    time_passed = 0
    system_temperature = determine_temperature(particles)
    #print('temperatura', type(system_temperature))
    df_chem = chemical_counter(particles, time_passed, system_temperature)

    #grid = Grid(LARGURA_CAIXA, ALTURA_CAIXA, GRID_SIZE)

    clock = pygame.time.Clock()

    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()

                # Pegar velocidades finais de todas as particulas
                for particle_instance in particles.values():
                    final_speed = np.sqrt(particle_instance.vel_x**2 + particle_instance.vel_y**2)
                    final_speeds.append(final_speed)

                maxwell_boltzmann_plot(final_speeds,name=NAME_BOLTZ) #desligado para teste

                df_chem = df_chem.fillna(0)
                df_chem.to_csv(NAME_CHEMICAL_CSV, index=False)
                #df_chem_molarity = convert_to_molarity(df_chem,1)
                #df_chem_molarity.to_csv(NAME_MOLARITY_CSV, index=False)
                #concentration_plot(df_chem,name=NAME_CONCENTRATION_PLOT)
                #integration_rate_law_plot(df_chem,name=NAME_INTEGRATION_RATE_LAW_PLOT)
                #data_fit = fit_concentration_plot(df_chem,name=NAME_FIT_CONCENTRATION_PLOT)
                #vel_rate_plot(data_fit,name=NAME_VEL_RATE)
                #print(df_chem_molarity)
                print(f'Temperatura Final do Sistema: {np.round(system_temperature,decimals=2)} K')
                exit()

        time_passed += DT
        #primeiro_digito = int(time_passed)

        #if (digito_atual == 0) or (digito_atual != primeiro_digito):
         #   primeiro_digito = digito_atual
            #print('novo df_chem')
        system_temperature = determine_temperature(particles)
        #print('temperatura', system_temperature)
        df_chem = chemical_counter(particles,time_passed,system_temperature,df_chem)
            

        #print('after_reaction')
        particles = select_particles(particles,sprites)
        #print(type(after_reaction_particles))

        # Update particle positions after collision detection
        for particle_name, particle_instance in particles.items():
            particle_instance.deslocar()
            particle_instance.next_position() #usado para calcular if colisao == True
            #print('Debugger:',particle_instance.x, particle_instance.y, particle_instance.x_future, particle_instance.y_future)

        # Update sprite positions
        for sprite, particle_instance in zip(sprites, particles.values()):
            sprite.rect.center = (particle_instance.x, particle_instance.y)

        #print(time_passed)

        screen.fill(WHITE)
        sprites.draw(screen)

        pygame.display.flip()
        clock.tick(FPS)

if __name__ == "__main__":
    main()
# Out:
# Before deletion: dict_keys(['Cl_1', 'Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_6', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_13', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_23', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_46', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Na_53', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_60', 'Na_61', 'Cl_62', 'Cl_63', 'Cl_64', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Cl_84', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Cl_91', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0'])
# Deleting particles with indices: Cl_1, Na_53
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_6', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_13', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_23', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_46', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_60', 'Na_61', 'Cl_62', 'Cl_63', 'Cl_64', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Cl_84', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Cl_91', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_6', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_13', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_23', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_46', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_60', 'Na_61', 'Cl_62', 'Cl_63', 'Cl_64', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Cl_84', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Cl_91', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1'])
# Deleting particles with indices: Na_23, Cl_64
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_6', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_13', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_46', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_60', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Cl_84', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Cl_91', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_6', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_13', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_46', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_60', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Cl_84', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Cl_91', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2'])
# Deleting particles with indices: Na_6, Cl_60
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_13', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_46', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Cl_84', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Cl_91', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_13', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_46', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Cl_84', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Cl_91', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3'])
# Deleting particles with indices: Na_13, Cl_84
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_46', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Cl_91', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_46', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Cl_91', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4'])
# Deleting particles with indices: Na_46, Cl_91
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Na_36', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_80', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5'])
# Deleting particles with indices: Na_36, Cl_80
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_8', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Cl_15', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6'])
# Deleting particles with indices: Na_8, Cl_15
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Cl_16', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Na_35', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7'])
# Deleting particles with indices: Cl_16, Na_35
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_29', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Na_69', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8'])
# Deleting particles with indices: Cl_29, Na_69
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_28', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_40', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9'])
# Deleting particles with indices: Na_28, Cl_40
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Cl_82', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Na_93', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10'])
# Deleting particles with indices: Cl_82, Na_93
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_19', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_44', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11'])
# Deleting particles with indices: Na_19, Cl_44
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Cl_12', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Cl_30', 'Na_31', 'Na_32', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12'])
# Deleting particles with indices: Cl_12, Na_32
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Cl_30', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Cl_30', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Na_61', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13'])
# Deleting particles with indices: Cl_30, Na_61
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Na_85', 'Cl_86', 'Cl_87', 'Cl_88', 'Cl_89', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14'])
# Deleting particles with indices: Na_85, Cl_89
# After deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14'])
# Before deletion: dict_keys(['Na_2', 'Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Cl_81', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15'])
# Deleting particles with indices: Na_2, Cl_81
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_41', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_78', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16'])
# Deleting particles with indices: Na_41, Cl_78
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Cl_42', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_97', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17'])
# Deleting particles with indices: Cl_42, Na_97
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_51', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Na_76', 'Cl_77', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18'])
# Deleting particles with indices: Cl_51, Na_76
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_77', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Na_24', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_77', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19'])
# Deleting particles with indices: Na_24, Cl_77
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_7', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Cl_63', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20'])
# Deleting particles with indices: Na_7, Cl_63
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Na_49', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Cl_56', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21'])
# Deleting particles with indices: Na_49, Cl_56
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Na_57', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Cl_88', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22'])
# Deleting particles with indices: Na_57, Cl_88
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Cl_52', 'Cl_54', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_90', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23'])
# Deleting particles with indices: Cl_52, Na_90
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Cl_54', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_14', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Cl_54', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_70', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24'])
# Deleting particles with indices: Na_14, Cl_70
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Cl_54', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_26', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Cl_54', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25'])
# Deleting particles with indices: Na_26, Cl_54
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_92', 'Cl_94', 'Na_95', 'Na_96', 'Na_98', 'Na_99', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26'])
# Deleting particles with indices: Cl_94, Na_99
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_92', 'Na_95', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26'])
# Before deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Na_67', 'Cl_68', 'Cl_71', 'Cl_72', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_92', 'Na_95', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27'])
# Deleting particles with indices: Na_67, Cl_72
# After deletion: dict_keys(['Cl_3', 'Cl_4', 'Cl_5', 'Na_9', 'Na_10', 'Cl_11', 'Na_17', 'Cl_18', 'Na_20', 'Cl_21', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Na_47', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Na_59', 'Cl_62', 'Na_65', 'Cl_66', 'Cl_68', 'Cl_71', 'Na_73', 'Cl_74', 'Na_75', 'Cl_79', 'Na_83', 'Cl_86', 'Cl_87', 'Na_92', 'Na_95', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27'])
# ...
# Deleting particles with indices: Na_20, Cl_79
# After deletion: dict_keys(['Cl_3', 'Cl_5', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_66', 'Cl_68', 'Cl_71', 'Na_73', 'Na_75', 'Cl_86', 'Cl_87', 'Na_92', 'Na_95', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32'])
# Before deletion: dict_keys(['Cl_3', 'Cl_5', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_37', 'Cl_38', 'Na_39', 'Na_43', 'Cl_45', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_66', 'Cl_68', 'Cl_71', 'Na_73', 'Na_75', 'Cl_86', 'Cl_87', 'Na_92', 'Na_95', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33'])
# Deleting particles with indices: Cl_37, Na_43
# After deletion: dict_keys(['Cl_3', 'Cl_5', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_66', 'Cl_68', 'Cl_71', 'Na_73', 'Na_75', 'Cl_86', 'Cl_87', 'Na_92', 'Na_95', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33'])
# Before deletion: dict_keys(['Cl_3', 'Cl_5', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Na_33', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_66', 'Cl_68', 'Cl_71', 'Na_73', 'Na_75', 'Cl_86', 'Cl_87', 'Na_92', 'Na_95', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34'])
# Deleting particles with indices: Cl_5, Na_33
# After deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_66', 'Cl_68', 'Cl_71', 'Na_73', 'Na_75', 'Cl_86', 'Cl_87', 'Na_92', 'Na_95', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34'])
# Before deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Cl_50', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_66', 'Cl_68', 'Cl_71', 'Na_73', 'Na_75', 'Cl_86', 'Cl_87', 'Na_92', 'Na_95', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35'])
# Deleting particles with indices: Cl_50, Na_95
# After deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_66', 'Cl_68', 'Cl_71', 'Na_73', 'Na_75', 'Cl_86', 'Cl_87', 'Na_92', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35'])
# Before deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_66', 'Cl_68', 'Cl_71', 'Na_73', 'Na_75', 'Cl_86', 'Cl_87', 'Na_92', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36'])
# Deleting particles with indices: Cl_66, Na_75
# After deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_68', 'Cl_71', 'Na_73', 'Cl_86', 'Cl_87', 'Na_92', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36'])
# Before deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Na_17', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_68', 'Cl_71', 'Na_73', 'Cl_86', 'Cl_87', 'Na_92', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37'])
# Deleting particles with indices: Na_17, Cl_87
# After deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_68', 'Cl_71', 'Na_73', 'Cl_86', 'Na_92', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37'])
# Before deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Cl_48', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_68', 'Cl_71', 'Na_73', 'Cl_86', 'Na_92', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38'])
# Deleting particles with indices: Cl_48, Na_92
# After deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_68', 'Cl_71', 'Na_73', 'Cl_86', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38'])
# Before deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Na_39', 'Cl_45', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_68', 'Cl_71', 'Na_73', 'Cl_86', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39'])
# Deleting particles with indices: Na_39, Cl_68
# After deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Cl_45', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_71', 'Na_73', 'Cl_86', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39'])
# Before deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_34', 'Cl_38', 'Cl_45', 'Na_55', 'Na_58', 'Cl_62', 'Na_65', 'Cl_71', 'Na_73', 'Cl_86', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39', 'NaCl_40'])
# Deleting particles with indices: Cl_34, Na_65
# After deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_38', 'Cl_45', 'Na_55', 'Na_58', 'Cl_62', 'Cl_71', 'Na_73', 'Cl_86', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39', 'NaCl_40'])
# Before deletion: dict_keys(['Cl_3', 'Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Na_31', 'Cl_38', 'Cl_45', 'Na_55', 'Na_58', 'Cl_62', 'Cl_71', 'Na_73', 'Cl_86', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39', 'NaCl_40', 'NaCl_41'])
# Deleting particles with indices: Cl_3, Na_31
# After deletion: dict_keys(['Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Cl_38', 'Cl_45', 'Na_55', 'Na_58', 'Cl_62', 'Cl_71', 'Na_73', 'Cl_86', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39', 'NaCl_40', 'NaCl_41'])
# Before deletion: dict_keys(['Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Cl_38', 'Cl_45', 'Na_55', 'Na_58', 'Cl_62', 'Cl_71', 'Na_73', 'Cl_86', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39', 'NaCl_40', 'NaCl_41', 'NaCl_42'])
# Deleting particles with indices: Na_55, Cl_86
# After deletion: dict_keys(['Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Cl_38', 'Cl_45', 'Na_58', 'Cl_62', 'Cl_71', 'Na_73', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39', 'NaCl_40', 'NaCl_41', 'NaCl_42'])
# Before deletion: dict_keys(['Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Na_27', 'Cl_38', 'Cl_45', 'Na_58', 'Cl_62', 'Cl_71', 'Na_73', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39', 'NaCl_40', 'NaCl_41', 'NaCl_42', 'NaCl_43'])
# Deleting particles with indices: Na_27, Cl_71
# After deletion: dict_keys(['Na_9', 'Cl_11', 'Cl_22', 'Cl_25', 'Cl_38', 'Cl_45', 'Na_58', 'Cl_62', 'Na_73', 'Na_96', 'Na_98', 'Cl_100', 'NaCl_0', 'NaCl_1', 'NaCl_2', 'NaCl_3', 'NaCl_4', 'NaCl_5', 'NaCl_6', 'NaCl_7', 'NaCl_8', 'NaCl_9', 'NaCl_10', 'NaCl_11', 'NaCl_12', 'NaCl_13', 'NaCl_14', 'NaCl_15', 'NaCl_16', 'NaCl_17', 'NaCl_18', 'NaCl_19', 'NaCl_20', 'NaCl_21', 'NaCl_22', 'NaCl_23', 'NaCl_24', 'NaCl_25', 'NaCl_26', 'NaCl_27', 'NaCl_28', 'NaCl_29', 'NaCl_30', 'NaCl_31', 'NaCl_32', 'NaCl_33', 'NaCl_34', 'NaCl_35', 'NaCl_36', 'NaCl_37', 'NaCl_38', 'NaCl_39', 'NaCl_40', 'NaCl_41', 'NaCl_42', 'NaCl_43'])
# Temperatura Final do Sistema: 0.57 K
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\venv\ilumpy-VS\lib\site-packages\IPython\core\interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#Debugging 14-11-2023 == FALSE_V1; LATEST STABLE == V1
#UI == pygame
#Implementado gráfico Max-Boltz
#Implementação do fit da Lei de Velocidade
#'future' funciona (inherited 6_10)
#Colisão inelástica e elástica implementada
#Colisão futura implementada em classe Particul
#Reação química feita + grafico conc./tempo
#Fazer: encontrar a lei de velocidade (derivadas)
#Problemas: 
# -não é vetorializado
# -baixa eficiência por itertools
# -NA_CL_INDEX como global
# -a = 'Na', b = 'Cl'; a = 'Cl', b = 'Na'-> e se forem 3?
# -intersection_position_checker que nao precisa checar tudo ?
# -reações que geram partículas grandes podem gerar intersecção com outra que está indo em direção a esta

# Catálise homogênea e heterogênea - ver sobre
# Adição do catalisador como parede -> vel == 0 True
# O código é sobre heterogenea
# Adicionado 'states' para entender quais colisões e reações

#Vetorialização:
#Usar arrays; mínimo de for's e while's (loops); numpy; scipy cdist; numpy.greater

import random
import warnings
import pygame
from pygame.locals import *
from sys import exit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lmfit.models import ExponentialModel, LinearModel
from lmfit import Model, Parameters
import itertools

# VERSION
VERSION = '6_19_3'

# Constants
FPS = 60
DT = 1/FPS
ALTURA_CAIXA = 500
LARGURA_CAIXA = 500
NUM_PARTICULAS = 100
#GRID_SIZE = 10
FUTURE_FACTOR = 1.5
TIPO_COLISAO = 'elastic'
COEFICIENTE_RESTITUICAO = 0.0 #coeficiente de restituição

AVOGADRO_CONSTANT = 6.022e23 #constante de avogadro
BOLTZMANN_CONSTANT = 1.380649e-23 #m2 kg s-2 K-1

MASSA_PROTON = 1.67262192e-27 #em Kg
MASSA_NEUTRON = 1.65e-27 #em Kg

NAME_BOLTZ = f'max-boltz_{VERSION}.png'
NAME_CONCENTRATION_PLOT = f'concentration_{VERSION}.png'
NAME_INTEGRATION_RATE_LAW_PLOT = f'inverse_concentration_{VERSION}.png'
NAME_FIT_CONCENTRATION_PLOT = f'fit_concentration_{VERSION}.png'
NAME_VEL_RATE = f'velocidade_reacao_{VERSION}.png'
NAME_CHEMICAL_CSV = f'df_chemical_data_{VERSION}.csv'
NAME_MOLARITY_CSV = f'df_molarity_data_{VERSION}.csv'

# Indexes de moléculas das reações
NA_CL_INDEX = 0
CHANCE_NACL_GLOBAL = 0.4 #chances de não acontecer a reação

# Colors
WHITE = (255, 255, 255)

class Particula:
    def __init__(self, p_type, state, massa, raio, vel_x, vel_y, x, y, chance_reaction,cor):
        self.p_type = p_type
        self.state = state
        self.massa = float(massa)
        self.raio = float(raio)
        self.vel_x = float(vel_x)
        self.vel_y = float(vel_y)
        self.x = float(x)
        self.y = float(y)
        self.x_future = None
        self.y_future = None
        self.chance_reaction = chance_reaction
        self.cor = cor
        self.sprite_pygame = self.sprite_pygame()

    def deslocar(self):

        self.x += self.vel_x * DT
        self.y += self.vel_y * DT

    def next_position(self):
        self.x_future = self.x + self.vel_x * DT * FUTURE_FACTOR
        self.y_future = self.y + self.vel_y * DT * FUTURE_FACTOR

        if self.x_future < self.raio or self.x_future > LARGURA_CAIXA - self.raio:
            if self.p_type == "Na":
                self.state = 'fixed'
                self.vel_x = 0.0
                self.vel_y = 0.0
                self.chance_reaction = 1.0
            else:    
                self.vel_x *= -1
            #print("ativada por x")
        if self.y_future < self.raio or self.y_future > ALTURA_CAIXA - self.raio:
            if self.p_type == "Na":
                self.state = 'fixed'
                self.vel_x = 0.0
                self.vel_y = 0.0
                self.chance_reaction = 1.0
            else:
                self.vel_y *= -1
            #print("ativada por y")

        #print('next_position')

    def sprite_pygame(self):
        circle = pygame.Surface((self.raio * 2, self.raio * 2), pygame.SRCALPHA)
        pygame.draw.circle(circle, self.cor, (self.raio, self.raio), self.raio)
        sprite = pygame.sprite.Sprite()
        sprite.image = circle
        sprite.rect = sprite.image.get_rect(center=(self.x, self.y))
        return sprite

def check_collision(p1, p2):

    p1.next_position() #proxima_posicao

    p2.next_position() #proxima_posicao

    distance_future = np.sqrt((p2.x_future - p1.x_future)**2 + (p2.y_future - p1.y_future)**2)
    #distance = np.sqrt((p2.x - p1.x)**2 + (p2.y - p1.y)**2)
    if (distance_future <= p1.raio + p2.raio) == True:
        return True
    else:
        return False


def reaction_collision(particles, p1, p1_index, p2, p2_index, sprites):

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    vel_new_particle = ((p1.massa * v1) + (p2.massa * v2)) / (p1.massa + p2.massa) #apenas momento conservado

    #print('arrays_reaction_v:', v1, v2)

    CM_x = (p1.massa * p1.x + p2.massa * p2.x) / (p1.massa + p2.massa)
    CM_y = (p1.massa * p1.y + p2.massa * p2.y) / (p1.massa + p2.massa)

    p1_chance = p1.chance_reaction #chance de acontecer a reação
    p2_chance = p2.chance_reaction

    remove_particles = []
    add_particles = []

    #print('arrays_reaction_CM:', CM_x, CM_y )

    #new_particles = particles.copy()
    #print('old_particles:', particles)


    if ((p1.p_type == 'Na' and p2.p_type == 'Cl') or (p1.p_type == 'Cl' and p2.p_type == 'Na')) and (p1_chance > CHANCE_NACL_GLOBAL or p2_chance > CHANCE_NACL_GLOBAL):
        #print(p1.p_type, p2.p_type, 'form NaCl')

        global NA_CL_INDEX

        p_type = 'NaCl'
        state = 'mobile'
        massa = (p1.massa + p2.massa)
        raio = 5
        vel_x = vel_new_particle[0]
        vel_y = vel_new_particle[1]
        x = CM_x
        y = CM_y
        #x_future = x + vel_x * DT * FUTURE_FACTOR
        #y_future = y + vel_y * DT * FUTURE_FACTOR
        chance_reaction = 0.00005
        cor = (125, 125, 125)
        nome_particula = f"{p_type}_{NA_CL_INDEX}" 
        particle_instance = Particula(p_type, state, massa,raio, vel_x, vel_y, x, y, chance_reaction,cor)

        sprites.add(particle_instance.sprite_pygame)
        
        NA_CL_INDEX += 1

        add_particles.extend([{nome_particula : particle_instance}])
        print(add_particles)

        #print("Before deletion:", particles.keys())
        #print(f"Deleting particles with indices: {p1_index}, {p2_index}")


        remove_particles.extend([p1_index, p2_index])
        print(remove_particles)

        #del particles[p1_index]
        #del particles[p2_index]

        #print("After deletion:", particles.keys())

        p1.sprite_pygame.kill()
        p2.sprite_pygame.kill()

        return add_particles, remove_particles

    if p1.state == 'mobile' and p2.state == 'mobile':
        resolve_collision(p1,p2,collision_type=TIPO_COLISAO)
        return add_particles, remove_particles

    if ((p1.p_type == 'Na' and p2.p_type == 'NaCl') or (p1.p_type == 'NaCl' and p2.p_type == 'Na')):
        #print('Na + NaCl')

        if p2.state == 'fixed':
            p1.vel_x *= -1
            p1.vel_y *= -1

        if p1.state == 'fixed':
            p2.vel_x *= -1
            p2.vel_y *= -1

        return add_particles, remove_particles


    if ((p1.p_type == 'Na' and p2.p_type == 'Na') or (p1.p_type == 'Na' and p2.p_type == 'Na')):

        if p2.state == 'fixed':
            p1.vel_x *= -1
            p2.vel_y *= -1

        if p1.state == 'fixed':
            p2.vel_x *= -1
            p2.vel_y *= -1

        return add_particles, remove_particles

    else:
        #print('does not react')
        #print('collision solved')
        resolve_collision(p1,p2,collision_type=TIPO_COLISAO)
        return add_particles, remove_particles

    #print('new_particles:',particles)
    #print()

    #return particles
    #return deve ser dado depois de cada if se nn o else roda e resolve a colisão


def resolve_collision(p1, p2, collision_type='elastic'):
    x1 = np.array([p1.x, p1.y])
    x2 = np.array([p2.x, p2.y])

    #print('arrays_x:', x1, x2)

    v1 = np.array([p1.vel_x, p1.vel_y])
    v2 = np.array([p2.vel_x, p2.vel_y])

    #print('arrays_v:', v1, v2)

    if collision_type == 'elastic' or collision_type == 'elastica':
        #print('elastica')

        C = 1

    if collision_type == 'partial_inelastic' or collision_type == 'parcial_inelastica':
        #print('inelastica')

        C = COEFICIENTE_RESTITUICAO

    new_v1 = v1 - ((((C * p2.massa) + p2.massa) / (p1.massa + p2.massa)) * ((np.dot((v1 - v2),(x1 - x2))) / ((np.linalg.norm(x1 - x2))**2)) * (x1 - x2))
    new_v2 = v2 - ((((C * p1.massa) + p1.massa) / (p1.massa + p2.massa)) * ((np.dot((v2 - v1),(x2 - x1))) / ((np.linalg.norm(x2 - x1))**2)) * (x2 - x1))

    p1.vel_x = new_v1[0]
    p1.vel_y = new_v1[1]
    p2.vel_x = new_v2[0]
    p2.vel_y = new_v2[1]

    #print('resolution',p1.vel_x, p1.vel_y, p2.vel_x, p2.vel_y)

#src_elastica = https://en.wikipedia.org/wiki/Elastic_collision#Two-dimensional_collision_with_two_moving_objects
#src_inelastica = https://physics.stackexchange.com/questions/708495/angle-free-two-dimensional-inelastic-collision-formula




def gerar_particula(n_particulas):
    particulas = {}

    #atomos
    atomos = {
        "Na": {"massa": 11*MASSA_PROTON + 12*MASSA_NEUTRON, "raio": 5, "color": (255, 0, 0)}, #approximations
        "Cl": {"massa": 17*MASSA_PROTON + 18*MASSA_NEUTRON, "raio": 5, "color": (0, 255, 0)},
        #"NaCl" : {"massa": 11*MASSA_PROTON + 12*MASSA_NEUTRON + 17*MASSA_PROTON + 18*MASSA_NEUTRON, "raio": 5, "color": (125, 125, 125)} #testes

    }

    for particle_index in range(1, n_particulas + 1):

        #escolha de distribuição aleatória
        atomos_selecionar = random.choice(list(atomos.keys()))

        attributes = atomos[atomos_selecionar]

        p_type = atomos_selecionar
        state = 'mobile'
        massa = attributes["massa"]
        raio = attributes["raio"]
        vel = random.uniform(100,600)
        vel_angle = np.random.uniform(0, 2 * np.pi)
        vel_x = vel * np.cos(vel_angle) #velocidade inicial não especificada
        vel_y = vel * np.sin(vel_angle)
        x = random.uniform(raio, LARGURA_CAIXA - raio)
        y = random.uniform(raio, ALTURA_CAIXA - raio)
        #x_future = x + vel_x * DT * FUTURE_FACTOR
        #y_future = y + vel_y * DT * FUTURE_FACTOR
        chance_reaction = 0.00005
        cor = attributes["color"]
        nome_particula = f"{atomos_selecionar}_{particle_index}" 
        particle_instance = Particula(p_type, state, massa, raio, vel_x, vel_y, x, y, chance_reaction, cor)
        particulas[nome_particula] = particle_instance
        #print(vel_x,vel_y,vel,vel_angle)

    return particulas

def select_particles(particles,sprites):
    copy_particles = particles.copy()
    all_update = []
    all_remove = []

    for (name_p1, instance_p1), (name_p2, instance_p2) in itertools.combinations(particles.items(), 2):
        #print((name_p1, type(instance_p1)), (name_p2, type(instance_p2)))
        if check_collision(instance_p1, instance_p2):
            #print('foi pra reacted')
            reacted_particles = reaction_collision(particles, instance_p1, name_p1, instance_p2, name_p2,sprites)

            all_update.extend(reacted_particles[0])
            all_remove.extend(reacted_particles[1])
            


    for particle_name in all_remove:
        del copy_particles[particle_name]

    for particle_dict in all_update:
        copy_particles.update(particle_dict)

    return copy_particles



def intersection_pos_checker(particles,iteration_max = 100):
    iteration_count = 0
    intersection = False
    #particle_pairs = np.array(list(itertools.permutations(particles.items(), 2)))
    for (name_p1, instance_p1), (name_p2, instance_p2) in itertools.combinations(particles.items(), 2):
        if check_collision(instance_p1, instance_p2):
                particle_move = random.choice([[name_p1,instance_p1], [name_p2,instance_p2]])
                new_x = random.uniform(particle_move[1].raio, LARGURA_CAIXA - (particle_move[1].raio))
                new_y = random.uniform(particle_move[1].raio, ALTURA_CAIXA - (particle_move[1].raio))
                particles[particle_move[0]].x = new_x
                particles[particle_move[0]].y = new_y
                iteration_count +=1
                #print(particles[particle_move[0]].y) #verificar coordenadas alteradas

                intersection = True
                if iteration_max == iteration_count:
                    warnings.warn(f'{iteration_max} iterações atingidas. Deve haver partículas sobrepostas. Altere o tamanho da caixa.')
                    return particles
    
    if intersection == True:
        #print('True')
        return intersection_pos_checker(particles)

    if intersection == False:
        #print('False')
        return particles


def create_particle_group_sprites(particles):
    sprites = pygame.sprite.Group()
    for particle_instance in particles.values():
        sprite = particle_instance.sprite_pygame
        sprites.add(sprite)
    #print(sprites)
    return sprites


def chemical_counter(particles,time_passed,system_temperature,df=pd.DataFrame()):
    chem_list = particles.keys()

    element_count = {}  # Initialize an empty dictionary to store element counts

    for item in chem_list:
        element = item.split('_')[0]  # Extract the element (part before the underscore)
        if element in element_count:
            element_count[element] += 1  # Increment the count if the element already exists
        else:
            element_count[element] = 1  # Initialize count to 1 if the element is encountered for the first time


    chem_array = np.concatenate((np.array([time_passed]),np.array([system_temperature]),np.array(list(element_count.values()))))
    df_chem = pd.DataFrame(chem_array).T
    df_chem.columns = np.concatenate((np.array(['Tempo [s]']),np.array(['Temperatura [K]']),np.array(list(element_count.keys()))))

    df_chem = pd.concat([df, df_chem], axis=0, ignore_index=True)

    return df_chem


def convert_to_molarity(df,liter):
    df_molar = df.copy()
    for column in range(1,df_molar.shape[1]):
        #print(column)
        df_molar.iloc[:,column] = ((df_molar.iloc[:,column]/AVOGADRO_CONSTANT)/liter)
    return df_molar

def determine_temperature(particles): #determina a temperatura baseada na média da vel. quadrada
    # sai de m*<v^2>/2 = 1/2 * 2 kt
    #nesse caso: <m*v**2>/2 = 0.5 * k*T
    array_vel_x = np.array([particle.vel_x for particle in particles.values()])
    array_vel_y = np.array([particle.vel_y for particle in particles.values()])
    array_massa = np.array([particle.massa for particle in particles.values()])

    mass_vel_average = np.mean(array_massa * np.sqrt((array_vel_x**2) + (array_vel_y**2)))
    temperature = mass_vel_average / (2*BOLTZMANN_CONSTANT) #dois graus de liberdade; sai em K

    return temperature

def fit_concentration_plot(df,name,sup_lim=-1):
    x_data = df.iloc[0:sup_lim,0].values

    y1_data = df.iloc[0:sup_lim,1].values #Cl
    y2_data = df.iloc[0:sup_lim,2].values #Na
    #print(len(y1_data),len(y2_data))

    modelo_exponencial_1 = ExponentialModel(prefix = 'exp_1_')
    modelo_exponencial_2 = ExponentialModel(prefix = 'exp_2_')
    print(f'Variável independente_1: {modelo_exponencial_1.independent_vars}')
    print(f'Parâmetros modelo_1: {modelo_exponencial_1.param_names}')
    print()
    print(f'Variável independente_2: {modelo_exponencial_2.independent_vars}')
    print(f'Parâmetros modelo_2: {modelo_exponencial_2.param_names}')

    params_exponencial_1 = modelo_exponencial_1.guess(y1_data,x=x_data)
    params_exponencial_2 = modelo_exponencial_2.guess(y2_data,x=x_data)
    params_exponencial_1.pretty_print()
    print()
    params_exponencial_2.pretty_print()

    resultado_fit_1 = modelo_exponencial_1.fit(y1_data, params_exponencial_1, x=x_data)
    resultado_fit_2 = modelo_exponencial_2.fit(y2_data, params_exponencial_2, x=x_data)
    print(resultado_fit_1.fit_report())
    print()
    print(resultado_fit_2.fit_report())

    fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    ax.plot(x_data, y1_data, label="Data Cl")
    ax.plot(x_data, y2_data, label="Data Na")
    ax.plot(x_data, resultado_fit_1.best_fit, label="Fit Cl")
    ax.plot(x_data, resultado_fit_2.best_fit, label="Fit Na")
    plt.title('Concentração x Tempo')
    plt.xlabel('Tempo [s]')
    plt.ylabel('Concentração [mol/L]')
    plt.legend()
    plt.grid(True)
    fig.tight_layout()
    fig.savefig(name)  # Salva a figura
    plt.show()

    data_vel_fit = {'x_data' : x_data,'resultado_fit_1' : resultado_fit_1, 'resultado_fit_2' : resultado_fit_2, 'y1_data' : y1_data, 'y2_data' : y2_data}

    return data_vel_fit


def vel_rate_plot(data_vel_fit,name):
    #print(data_vel_fit['resultado_fit_1'])
    #print(data_vel_fit['resultado_fit_1'].best_fit)
    derivative = -np.diff(data_vel_fit['resultado_fit_1'].best_fit,n=1)
    #print(derivative)
    concentrations = data_vel_fit['y1_data'][:-1]


    # Define the quadratic model function
    def quadratic_model(x, a, b, c):
        return a * x**2 + b * x + c
        
    mod = Model(quadratic_model)

# Automatically guess initial parameter values
    params_quadratic = Parameters()
    params_quadratic.add('a', value=1.0)
    params_quadratic.add('b', value=1.0)
    params_quadratic.add('c', value=1.0)

    # Perform the fit
    result_quadratic = mod.fit(derivative, params_quadratic, x=concentrations)

    # Print and visualize the fit results
    print(result_quadratic.fit_report())
    a_value = result_quadratic.params['a'].value
    b_value = result_quadratic.params['b'].value
    c_value = result_quadratic.params['c'].value

    fig2, ax2 = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    #ax2.plot(data_vel_fit['y1_data'], derivative_1, label = "Velocidade em Cl")
    ax2.plot(1/concentrations,derivative, label = "Concentração de Cl")
    ax2.plot(1/concentrations, result_quadratic.best_fit, label=f"Coeficiente K: {a_value}", color='red')

    plt.title('Fit d[Concentração]/dt x Concentração')
    plt.xlabel('Concentração')
    plt.ylabel('Velocidade')
    plt.legend()
    plt.grid(True)
    fig2.tight_layout()
    fig2.savefig(name)  # Salva a figura
    plt.show()

def maxwell_boltzmann_plot(final_speeds,name):
    # Barplot/histograma das velocidades Max-Boltz.
    fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    plt.hist(final_speeds, bins=25, color='blue', edgecolor='black', alpha=0.7)
    plt.xlabel('Velocidade [m/s]')
    plt.ylabel('Frequência [un]')
    plt.title('Histograma das velocidades finais')
    plt.grid(True)
    fig.tight_layout()
    fig.savefig(name)  # Salva a figura
    plt.show()

def concentration_plot(df,name):
    # Lineplot das concentrações/tempo.
    fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    for y_axis, labels in zip(df.columns[2:],list(df.columns)[2:]):
        plt.plot(df['Tempo [s]'],(df[y_axis]),alpha=0.7, label=labels)
    plt.legend()
    plt.xlabel('Tempo [s]')
    plt.ylabel('Concentração [mol/L]')
    plt.title('Evolução temporal das concentrações')
    plt.grid(True)
    fig.tight_layout()
    fig.savefig(name)  # Salva a figura
    plt.show()

def integration_rate_law_plot(df,name):
    inverse = (1/df['NaCl']).replace(np.inf,0,inplace=True)
    print('inversa', inverse)
    # Lineplot das concentrações/tempo.
    fig, ax = plt.subplots(figsize=(6, 6))  # Cria caixa para plot
    model = LinearModel()
    params = model.make_params(slope=1, intercept=1)
    result = model.fit(inverse, params, x=df['Tempo [s]'])
    slope = result.params['slope'].value
    intercept = result.params['intercept'].value
    plt.scatter(df['Tempo [s]'], inverse, label='Original Data')
    plt.plot(df['Tempo [s]'], result.best_fit, label='Linear Fit', color='red') 


    #plt.plot(df['Tempo [s]'],(df[y_axis]),alpha=0.7, label=labels)
    plt.legend()
    plt.xlabel('Tempo [s]')
    plt.ylabel('1/[NaCl]')
    plt.title('Evolução temporal da integração da lei de velocidade')
    plt.grid(True)
    fig.tight_layout()
    fig.savefig(name)  # Salva a figura
    plt.show()



def main():
    final_speeds = []
    pygame.init()
    screen = pygame.display.set_mode((LARGURA_CAIXA, ALTURA_CAIXA))
    pygame.display.set_caption("Collision Simulation")

    particles = gerar_particula(NUM_PARTICULAS)
    particles = intersection_pos_checker(particles)
    sprites = create_particle_group_sprites(particles)

    #digito_atual = 0
    time_passed = 0
    system_temperature = determine_temperature(particles)
    #print('temperatura', type(system_temperature))
    df_chem = chemical_counter(particles, time_passed, system_temperature)

    #grid = Grid(LARGURA_CAIXA, ALTURA_CAIXA, GRID_SIZE)

    clock = pygame.time.Clock()

    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()

                # Pegar velocidades finais de todas as particulas
                for particle_instance in particles.values():
                    final_speed = np.sqrt(particle_instance.vel_x**2 + particle_instance.vel_y**2)
                    final_speeds.append(final_speed)

                maxwell_boltzmann_plot(final_speeds,name=NAME_BOLTZ) #desligado para teste

                df_chem = df_chem.fillna(0)
                df_chem.to_csv(NAME_CHEMICAL_CSV, index=False)
                #df_chem_molarity = convert_to_molarity(df_chem,1)
                #df_chem_molarity.to_csv(NAME_MOLARITY_CSV, index=False)
                concentration_plot(df_chem,name=NAME_CONCENTRATION_PLOT)
                integration_rate_law_plot(df_chem,name=NAME_INTEGRATION_RATE_LAW_PLOT)
                #data_fit = fit_concentration_plot(df_chem,name=NAME_FIT_CONCENTRATION_PLOT)
                #vel_rate_plot(data_fit,name=NAME_VEL_RATE)
                #print(df_chem_molarity)
                print(f'Temperatura Final do Sistema: {np.round(system_temperature,decimals=2)} K')
                exit()

        time_passed += DT
        #primeiro_digito = int(time_passed)

        #if (digito_atual == 0) or (digito_atual != primeiro_digito):
         #   primeiro_digito = digito_atual
            #print('novo df_chem')
        system_temperature = determine_temperature(particles)
        #print('temperatura', system_temperature)
        df_chem = chemical_counter(particles,time_passed,system_temperature,df_chem)
            

        #print('after_reaction')
        particles = select_particles(particles,sprites)
        #print(type(after_reaction_particles))

        # Update particle positions after collision detection
        for particle_name, particle_instance in particles.items():
            particle_instance.deslocar()
            particle_instance.next_position() #usado para calcular if colisao == True
            #print('Debugger:',particle_instance.x, particle_instance.y, particle_instance.x_future, particle_instance.y_future)

        # Update sprite positions
        for sprite, particle_instance in zip(sprites, particles.values()):
            sprite.rect.center = (particle_instance.x, particle_instance.y)

        #print(time_passed)

        screen.fill(WHITE)
        sprites.draw(screen)

        pygame.display.flip()
        clock.tick(FPS)

if __name__ == "__main__":
    main()
# Out:
# [{'NaCl_0': <__main__.Particula object at 0x000001C7F2D67040>}]
# ['Cl_42', 'Na_89']
# [{'NaCl_1': <__main__.Particula object at 0x000001C7F2FE0460>}]
# ['Cl_65', 'Na_72']
# [{'NaCl_2': <__main__.Particula object at 0x000001C7F2E2C4C0>}]
# ['Na_60', 'Cl_98']
# [{'NaCl_3': <__main__.Particula object at 0x000001C7F2FE0D90>}]
# ['Cl_19', 'Na_100']
# [{'NaCl_4': <__main__.Particula object at 0x000001C7D1C18820>}]
# ['Cl_18', 'Na_32']
# [{'NaCl_5': <__main__.Particula object at 0x000001C7F430FF70>}]
# ['Na_3', 'Cl_46']
# [{'NaCl_6': <__main__.Particula object at 0x000001C7F2FE07C0>}]
# ['Na_48', 'Cl_80']
# [{'NaCl_7': <__main__.Particula object at 0x000001C7D1C18E20>}]
# ['Na_12', 'Cl_29']
# [{'NaCl_8': <__main__.Particula object at 0x000001C7F2D87670>}]
# ['Na_22', 'Cl_83']
# [{'NaCl_9': <__main__.Particula object at 0x000001C7F2FE0D30>}]
# ['Cl_30', 'Na_39']
# [{'NaCl_10': <__main__.Particula object at 0x000001C7F2C44100>}]
# ['Na_16', 'Cl_58']
# [{'NaCl_11': <__main__.Particula object at 0x000001C7F2DC1700>}]
# ['Na_9', 'Cl_69']
# [{'NaCl_12': <__main__.Particula object at 0x000001C7D1B9F7C0>}]
# ['Cl_43', 'Na_92']
# [{'NaCl_13': <__main__.Particula object at 0x000001C7F2DC1580>}]
# ['Cl_13', 'Na_34']
# [{'NaCl_14': <__main__.Particula object at 0x000001C7F31B3AC0>}]
# ['Cl_27', 'Na_53']
# [{'NaCl_15': <__main__.Particula object at 0x000001C7F2C39130>}]
# ['Cl_41', 'Na_54']
# [{'NaCl_16': <__main__.Particula object at 0x000001C7F2C39D00>}]
# ['Na_14', 'Cl_76']
# [{'NaCl_17': <__main__.Particula object at 0x000001C7F2DF5820>}]
# ['Na_63', 'Cl_91']
# [{'NaCl_18': <__main__.Particula object at 0x000001C7F2C399D0>}]
# ['Na_8', 'Cl_15']
# [{'NaCl_19': <__main__.Particula object at 0x000001C7F2FE0850>}]
# ['Na_84', 'Cl_97']
# [{'NaCl_20': <__main__.Particula object at 0x000001C7F2DC1C40>}]
# ['Na_28', 'Cl_67']
# [{'NaCl_21': <__main__.Particula object at 0x000001C7F2DC1550>}]
# ['Na_51', 'Cl_62']
# [{'NaCl_22': <__main__.Particula object at 0x000001C7F430F0D0>}]
# ['Cl_24', 'Na_66']
# [{'NaCl_23': <__main__.Particula object at 0x000001C7F2D878B0>}]
# ['Na_81', 'Cl_87']
# [{'NaCl_24': <__main__.Particula object at 0x000001C7F2DC1100>}]
# ['Na_44', 'Cl_52']
# [{'NaCl_25': <__main__.Particula object at 0x000001C7F430F700>}]
# ['Na_25', 'Cl_79']
# [{'NaCl_26': <__main__.Particula object at 0x000001C7F2C39370>}]
# ['Cl_38', 'Na_96']
# [{'NaCl_27': <__main__.Particula object at 0x000001C7F2D73FD0>}]
# ['Cl_47', 'Na_95']
# [{'NaCl_28': <__main__.Particula object at 0x000001C7F31B3F40>}]
# ['Na_5', 'Cl_73']
# [{'NaCl_29': <__main__.Particula object at 0x000001C7F2C39D60>}]
# ['Cl_57', 'Na_82']
# [{'NaCl_30': <__main__.Particula object at 0x000001C7F2D63190>}]
# ['Na_23', 'Cl_71']
# [{'NaCl_31': <__main__.Particula object at 0x000001C7F2DD5A00>}]
# ['Na_35', 'Cl_59']
# [{'NaCl_32': <__main__.Particula object at 0x000001C7F2DD57C0>}]
# ['Cl_17', 'Na_40']
# [{'NaCl_33': <__main__.Particula object at 0x000001C7F2D73F10>}]
# ['Cl_78', 'Na_88']
# [{'NaCl_34': <__main__.Particula object at 0x000001C7F430FD00>}]
# ['Na_31', 'Cl_86']
# [{'NaCl_35': <__main__.Particula object at 0x000001C7D1B9F100>}]
# ['Cl_37', 'Na_56']
# [{'NaCl_36': <__main__.Particula object at 0x000001C7F2D87A90>}]
# ['Cl_55', 'Na_93']
# [{'NaCl_37': <__main__.Particula object at 0x000001C7F2E2C5B0>}]
# ['Cl_1', 'Na_11']
# [{'NaCl_38': <__main__.Particula object at 0x000001C7D1C18400>}]
# ['Na_45', 'Cl_75']
# inversa None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 651
#     648         clock.tick(FPS)
#     650 if __name__ == "__main__":
# --> 651     main()
#
# Cell In[4], line 610, in main()
#     607 #df_chem_molarity = convert_to_molarity(df_chem,1)
#     608 #df_chem_molarity.to_csv(NAME_MOLARITY_CSV, index=False)
#     609 concentration_plot(df_chem,name=NAME_CONCENTRATION_PLOT)
# --> 610 integration_rate_law_plot(df_chem,name=NAME_INTEGRATION_RATE_LAW_PLOT)
#     611 #data_fit = fit_concentration_plot(df_chem,name=NAME_FIT_CONCENTRATION_PLOT)
#     612 #vel_rate_plot(data_fit,name=NAME_VEL_RATE)
#     613 #print(df_chem_molarity)
#     614 print(f'Temperatura Final do Sistema: {np.round(system_temperature,decimals=2)} K')
#
# Cell In[4], line 554, in integration_rate_law_plot(df, name)
#     552 model = LinearModel()
#     553 params = model.make_params(slope=1, intercept=1)
# --> 554 result = model.fit(inverse, params, x=df['Tempo [s]'])
#     555 slope = result.params['slope'].value
#     556 intercept = result.params['intercept'].value
#
# File C:\venv\ilumpy-VS\lib\site-packages\lmfit\model.py:1103, in Model.fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, calc_covar, max_nfev, coerce_farray, **kwargs)
#    1097     fit_kws = {}
#    1099 output = ModelResult(self, params, method=method, iter_cb=iter_cb,
#    1100                      scale_covar=scale_covar, fcn_kws=kwargs,
#    1101                      nan_policy=self.nan_policy, calc_covar=calc_covar,
#    1102                      max_nfev=max_nfev, **fit_kws)
# -> 1103 output.fit(data=data, weights=weights)
#    1104 output.components = self.components
#    1105 return output
#
# File C:\venv\ilumpy-VS\lib\site-packages\lmfit\model.py:1467, in ModelResult.fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1465 self.userkws.update(kwargs)
#    1466 self.init_fit = self.model.eval(params=self.params, **self.userkws)
# -> 1467 _ret = self.minimize(method=self.method)
#    1468 self.model.post_fit(_ret)
#    1469 _ret.params.create_uvars(covar=_ret.covar)
#
# File C:\venv\ilumpy-VS\lib\site-packages\lmfit\minimizer.py:2345, in Minimizer.minimize(self, method, params, **kws)
#    2342         if (key.lower().startswith(user_method) or
#    2343                 val.lower().startswith(user_method)):
#    2344             kwargs['method'] = val
# -> 2345 return function(**kwargs)
#
# File C:\venv\ilumpy-VS\lib\site-packages\lmfit\minimizer.py:1651, in Minimizer.leastsq(self, params, max_nfev, **kws)
#    1649 result.call_kws = lskws
#    1650 try:
# -> 1651     lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1652 except AbortFitException:
#    1653     pass
#
# File C:\venv\ilumpy-VS\lib\site-packages\scipy\optimize\_minpack_py.py:415, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     413 if not isinstance(args, tuple):
#     414     args = (args,)
# --> 415 shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     416 m = shape[0]
#     418 if n > m:
#
# File C:\venv\ilumpy-VS\lib\site-packages\scipy\optimize\_minpack_py.py:25, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      23 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      24                 output_shape=None):
# ---> 25     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      26     if (output_shape is not None) and (shape(res) != output_shape):
#      27         if (output_shape[0] != 1):
#
# File C:\venv\ilumpy-VS\lib\site-packages\lmfit\minimizer.py:548, in Minimizer.__residual(self, fvars, apply_bounds_transformation)
#     545     self.result.success = False
#     546     raise AbortFitException(f"fit aborted: too many function evaluations {self.max_nfev}")
# --> 548 out = self.userfcn(params, *self.userargs, **self.userkws)
#     550 if callable(self.iter_cb):
#     551     abort = self.iter_cb(params, self.result.nfev, out,
#     552                          *self.userargs, **self.userkws)
#
# File C:\venv\ilumpy-VS\lib\site-packages\lmfit\model.py:814, in Model._residual(self, params, data, weights, **kwargs)
#     808     msg = ('The model function generated NaN values and the fit '
#     809            'aborted! Please check your model function and/or set '
#     810            'boundaries on parameters where applicable. In cases like '
#     811            'this, using "nan_policy=\'omit\'" will probably not work.')
#     812     raise ValueError(msg)
# --> 814 diff = model - data
#     816 if diff.dtype == complex:
#     817     # data/model are complex
#     818     diff = diff.ravel().view(float)
#
# TypeError: unsupported operand type(s) for -: 'float' and 'NoneType'
